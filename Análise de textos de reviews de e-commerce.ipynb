# %% [markdown]
# # Análise de reviews de produtos usando NLP
#
# O presente trabalho pretende analisar os textos de revisão de produtos da base de dados obtida na plataforma Kaggle. Para isso serão usadas bibliotecas Python de processamento de linguagem natural já conhecidas como Spacy, Sci-kit Learn e.
#
# https://www.kaggle.com/olistbr/brazilian-ecommerce
#
# Objetivos:
# - Encontrar caracaterísticas que distinguam textos de reviews com notas altas e com notas baixas.
# - Analisar textos com análise de sentimentos e identificar textos muito negativos, mas que possuam notas altas.

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
import spacy
from nltk import corpus
import nltk
import re
from unicodedata import normalize
import itertools as it
import numpy as np

# %%
# Definindo a máquina virtual Java para o lematizador e pos-tagger de Stanford
from py4j.java_gateway import JavaGateway

gg = JavaGateway.launch_gateway(classpath="./java/lemmatizerpt.jar;./java/py4j0.10.8.1.jar;./java/stanford-postagger.jar;./java/lemport-0.9.7.jar")

# %%
e_set = pd.read_csv("./brazilian-ecommerce/olist_public_dataset_v2.csv")
e_set.head()
# Out:
#                            order_id order_status  order_products_value  \
# 0  b95df3cef5297e79ef709ba256518f6f    delivered                349.90
# 1  59af46052a799e80e2f0c665c587731d    delivered                 15.00
# 2  a3e6136894621db402a772c6bc72a12a    delivered                238.90
# 3  b675ea5a618922f6e679e30531b8957b    delivered                 29.99
# 4  195a8be6794c487fe6cfbb97b7c61902    delivered                295.99
#
#    order_freight_value  order_items_qty  order_sellers_qty  \
# 0                13.84                1                  1
# 1                15.10                1                  1
# 2                18.00                1                  1
# 3                18.23                1                  1
# 4                47.65                1                  1
#
#      order_purchase_timestamp            order_aproved_at  \
# 0  2017-01-31 17:19:01.000000  2017-02-01 02:41:21.549551
# 1  2017-09-09 19:52:54.000000  2017-09-10 20:03:31.535281
# 2  2017-01-30 17:00:09.000000  2017-01-30 17:31:25.438253
# 3  2018-03-11 18:18:36.000000  2018-03-11 18:30:37.931962
# 4  2017-04-20 08:01:08.000000  2017-04-25 08:05:40.405383
#
#   order_estimated_delivery_date order_delivered_customer_date  \
# 0    2017-03-15 00:00:00.000000    2017-02-06 11:04:24.154259
# 1    2017-10-02 00:00:00.000000    2017-09-13 20:17:41.296915
# 2    2017-03-07 00:00:00.000000    2017-02-06 15:43:04.758566
# 3    2018-04-03 00:00:00.000000    2018-04-03 20:36:43.778451
# 4    2017-05-24 00:00:00.000000    2017-05-04 18:47:45.721758
#
#              ...             product_name_lenght product_description_lenght  \
# 0            ...                              51                        625
# 1            ...                              44                       1428
# 2            ...                              55                        637
# 3            ...                              55                        617
# 4            ...                              49                        558
#
#   product_photos_qty                        product_id  \
# 0                  1  6cdd53843498f92890544667809f1595
# 1                  2  ae5cad88462eb7b7b61401e31c45618e
# 2                  1  0c9ff9d8ed9b9bdd825487b3a66e05f5
# 3                  1  ad0a798e7941f3a5a2fb8139cb62ad78
# 4                  2  eaf2046d4c87809247a30050ea13df03
#
#                           review_id  review_score  review_comment_title  \
# 0  b95df3cef5297e79ef709ba256518f6f             5                   NaN
# 1  59af46052a799e80e2f0c665c587731d             5                   NaN
# 2  a3e6136894621db402a772c6bc72a12a             5                   NaN
# 3  b675ea5a618922f6e679e30531b8957b             4                   NaN
# 4  195a8be6794c487fe6cfbb97b7c61902             5                   NaN
#
#                               review_comment_message  \
# 0                                                NaN
# 1  entrega em 2 dias produto c boa qualidade otim...
# 2  produto veio antes do prazo informado muito ob...
# 3                                                NaN
# 4                                                NaN
#
#          review_creation_date    review_answer_timestamp
# 0  2017-02-07 00:00:00.000000  2017-02-09 02:37:37+00:00
# 1  2017-09-14 00:00:00.000000  2017-09-15 03:43:47+00:00
# 2  2017-02-07 00:00:00.000000  2017-02-10 14:18:53+00:00
# 3  2018-04-04 00:00:00.000000  2018-04-05 02:52:31+00:00
# 4  2017-05-05 00:00:00.000000  2017-05-08 15:20:18+00:00
#
# [5 rows x 25 columns]

# %% [markdown]
# # Padronizando o DataFrame
#
# Retiramos todas as linhas que não possuem reviews para analisar somente os textos.

# %%
e_work_set = e_set[['order_products_value','review_score', 'review_comment_message']].copy()
e_work_set = e_work_set.dropna().reset_index(drop = True)
e_work_set.head()
# Out:
#    order_products_value  review_score  \
# 0                  15.0             5
# 1                 238.9             5
# 2                 160.0             4
# 3                  25.0             3
# 4                 187.0             5
#
#                               review_comment_message
# 0  entrega em 2 dias produto c boa qualidade otim...
# 1  produto veio antes do prazo informado muito ob...
# 2           chegou bem antes do prazo ótimo vendedor
# 3                                  gostei do produto
# 4  o produto veio certinho muito bem embalado e b...

# %% [markdown]
# ## Pre-processamento

# %% [markdown]
# ## Remoção de acentuação

# %%
def remover_acentos(txt):
    return normalize('NFKD', txt).encode('ASCII', 'ignore').decode('ASCII')

# %% [markdown]
# ## Remoção de pontuação
#
# Será feita a remoção de acentuação usando uma expressão regular simples.

# %%
pattern = re.compile('[^a-zA-Z\d\s]')
#print(re.sub(pattern,'','Amanhã, iremos a casa!'))

# %% [markdown]
# ## Remoção de Stopwords
#
# As stopwords, palavras que não possuem sentido significativo para a sentença são retiradas através da corpora disponibilizada pela bibliteca NLTK.

# %%
stop_words = set(corpus.stopwords.words('portuguese'))

stop_words_norm = []
for i in stop_words:
    word = remover_acentos(i)
    stop_words_norm.append(word)
    
stop_words_norm.remove('nao')

# %% [markdown]
# ## Lematização

# %% [markdown]
# A lematização é a redução da palavra a sua forma mais básica, ou seja, substanttivos na forma masculina e no singular, verbos no infinitivo.
#
# O procedimento foi feito adptando o lemmatizador stanford, feito em Java, usando a biblioteca Py4J que cria uma interface com Java para Python

# %% [markdown]
# ## Realização do pré processamento
#
# Ao final do pré-processamento obteremos um texto simplificado, mas que padroniza a estrutura dos comentários e facilita na nossa análise.

# %%
gg = JavaGateway.launch_gateway(classpath="./java/lemmatizerpt.jar;./java/py4j0.10.8.1.jar;./java/stanford-postagger.jar;./java/lemport-0.9.7.jar")
lemmatizer = gg.jvm.lemmatizer.LemmatizerInterface()    

for index,row in e_work_set.iterrows():
    
    # Retiramos a pontuação usando Regex.
    lista_tks = []
    for tk in e_work_set['review_comment_message'][index].split():
        lista_tks.append(re.sub(pattern,'',tk))
    tk_reviews = lista_tks
    
    # Reduz a palavra ao seu lema.
    
    lemmatizer.processLemmas(' '.join(tk_reviews))
    
    list_lemmas = [i for i in lemmatizer.getLemmas()]
    list_tags = [j for j in lemmatizer.getPosTags()]    

    # Removemos os acentos inicialmente.
    tk_reviews = remover_acentos(' '.join(list_lemmas))
       
    # Retira Stopwords.
    tk_reviews = [w for w in tk_reviews.split() if not w in stop_words_norm]
    
    e_work_set.loc[index,'review_tratada'] = ' '.join(tk_reviews)
    e_work_set.loc[index,'pos_tags'] = ' '.join(list_tags)

# %%
e_work_set.to_csv('review_lematizada.csv',encoding = 'utf-8',index = False)

# %%
e_work_set.head()
# Out:
#    order_products_value  review_score  \
# 0                  15.0             5
# 1                 238.9             5
# 2                 160.0             4
# 3                  25.0             3
# 4                 187.0             5
#
#                               review_comment_message  \
# 0  entrega em 2 dias produto c boa qualidade otim...
# 1  produto veio antes do prazo informado muito ob...
# 2           chegou bem antes do prazo ótimo vendedor
# 3                                  gostei do produto
# 4  o produto veio certinho muito bem embalado e b...
#
#                                       review_tratada  \
# 0  entrega 2 dia produto c bom qualidade otimo cu...
# 1  produto vir antes prazo informar obrigar agili...
# 2               chegar bem antes prazo timo vendedor
# 3                                     gostar produto
# 4  produto vir certo bem embalar bem antes prazo ...
#
#                                             pos_tags
# 0                    n prp num n n adv adj n adj n n
# 1            n v-fin prp adj n v-pcp adv v-pcp n adv
# 2                          v-fin adv adv adj n adj n
# 3                                        v-fin adj n
# 4  art n v-fin adj adv adv v-pcp conj-c adv adv a...

# %% [markdown]
# # Extraindo Features das reviews tokenizadas
#
# Agora vamos extrair algumas características das reviews para analisarmos separadamente os textos de reviews para cada pontuação.

# %%
e_set_rev_1 = e_work_set[e_work_set['review_score'] == 1].reset_index(drop = True)
e_set_rev_2 = e_work_set[e_work_set['review_score'] == 2].reset_index(drop = True)
e_set_rev_3 = e_work_set[e_work_set['review_score'] == 3].reset_index(drop = True)
e_set_rev_4 = e_work_set[e_work_set['review_score'] == 4].reset_index(drop = True)
e_set_rev_5 = e_work_set[e_work_set['review_score'] == 5].reset_index(drop = True)
e_set_rev_1.head()
# Out:
#    order_products_value  review_score  \
# 0                134.90             1
# 1                329.99             1
# 2                251.90             1
# 3                979.00             1
# 4                 62.70             1
#
#                               review_comment_message  \
# 0       o correio ainda não fez a entrega to furioso
# 1  não recebi o meu produto e nem fui avisada da ...
# 2  comprei um produto e recebi outro e inferior g...
# 3  não comprem só vai dar dor de cabeça o produto...
# 4  comprei 2 produtos iguais porém em cores difer...
#
#                                       review_tratada  \
# 0             correio ainda fazer entrega to furioso
# 1  receber produto ser avisar faltar item loja en...
# 2  comprar produto receber outro inferior gostar ...
# 3    comprar s ir dar dor cabea produto nunca chegar
# 4  comprar 2 produto igual porm cor diferente che...
#
#                                             pos_tags
# 0            art n adv pron-pers v-fin art n adj adj
# 1  pron-pers v-fin art pron-det n conj-c adv v-fi...
# 2  v-fin art n conj-c v-fin pron-det conj-c adj v...
# 3  pron-pers v-fin pron-pers v-fin v-inf n prp n ...
# 4  v-fin num n adj n prp n adj v-fin prp pron-det...

# %% [markdown]
# ## Análise Exploratória
#
# Será mostrado, como exemplo, o código para extração de cada feature nas reviews de nota 1. Em seguida mostraremos apenas os resultados obtidos para as reviews agrupadas por nota.

# %% [markdown]
# ## Media de Tokens
#
# Com o propósito de analisar o tamanho do texto escrito pelos consumidores ao avaliar um produto, foi feita uma média dos tokens para cada nota.

# %%
def media_tokens(df):
    vectorizer = CountVectorizer(encoding = 'utf_8')
    reviews = []

    for row in df.itertuples():
        reviews.append(row[3])

    tokenized_reviews_all = vectorizer.fit_transform(reviews)
    nr_medio_de_tokens_1 = tokenized_reviews_all.toarray().sum()/len(e_set_rev_1)
    return nr_medio_de_tokens_1

# %%
print('Média de Tokens para reviews de nota 1: %.2f' % media_tokens(e_set_rev_1))
print('Média de Tokens para reviews de nota 2: %.2f' % media_tokens(e_set_rev_2))
print('Média de Tokens para reviews de nota 3: %.2f' % media_tokens(e_set_rev_3))
print('Média de Tokens para reviews de nota 4: %.2f' % media_tokens(e_set_rev_4))
print('Média de Tokens para reviews de nota 5: %.2f' % media_tokens(e_set_rev_5))
# Out:
# Média de Tokens para reviews de nota 1: 15.83
# Média de Tokens para reviews de nota 2: 3.80
# Média de Tokens para reviews de nota 3: 5.67
# Média de Tokens para reviews de nota 4: 6.20
# Média de Tokens para reviews de nota 5: 17.05

# %% [markdown]
# ## Análise de Sentimento
#
# A análise de sentimento proposta é feita de maneira bem simples. Baseado em uma lista de termos positivos e uma lista de termos negativos calculamos a porcentagem de palavras positivas e negativas no total. Palavras que não estão classificadas em positivas e negativas serão consideradas neutras.
#
# As listas são provenientes do site Kaggle.
# https://www.kaggle.com/rtatman/sentiment-lexicons-for-81-languages

# %% [markdown]
# ### Importando léxico de palavras negativas

# %%
palavras_negativas = []

with open('./sentiment-lexicons/negative_words_pt.txt','r',encoding = 'utf_8') as f:
    for line in f.readlines():
        palavras_negativas.append(line)


lista_negativas = []
for i in palavras_negativas:
    palavra = i.replace('\n', '')
    lista_negativas.append(remover_acentos(palavra))   

lista_negativas = set(lista_negativas)

# %% [markdown]
# ### Importando léxico de palavras positivas

# %%
palavras_positivas = []

with open('./sentiment-lexicons/positive_words_pt.txt','r',encoding = 'utf_8') as f:
    for line in f.readlines():
        palavras_positivas.append(line)


lista_positivas = []
for i in palavras_positivas:
    palavra = i.replace('\n', '')
    lista_positivas.append(remover_acentos(palavra))   

lista_positivas = set(lista_positivas)

# %% [markdown]
# ### Definindo função para contagem de tokens positivos e negativos

# %%
# Recebe uma string e comparar as palavras que estão no léxico positivo e negativo

def sent_count(text):
    pos_count = 0
    neg_count = 0
    for token in text.split():
        if token in lista_positivas:
            pos_count += 1
            
        elif token in lista_negativas:
            neg_count += 1
            
    return((pos_count,neg_count))

# %%
for index,row in e_work_set.iterrows():
    x = e_work_set['review_tratada'][index]

    if x == '':
        continue
    sentimentos = sent_count(x)
    e_work_set.loc[index,'nr_tk_positivos'] = sentimentos[0]
    e_work_set.loc[index,'porcent_tk_positivos'] = sentimentos[0]/len(x.split())
    e_work_set.loc[index,'nr_tk_negativos'] = sentimentos[1]
    e_work_set.loc[index,'porcent_tk_negativos'] = sentimentos[1]/len(x.split())
    
    if e_work_set['porcent_tk_positivos'][index] == e_work_set['porcent_tk_negativos'][index]:
        e_work_set.loc[index,'sentimento'] = 'Neutro'
        
    elif e_work_set['porcent_tk_positivos'][index] > e_work_set['porcent_tk_negativos'][index]:
        e_work_set.loc[index,'sentimento'] = 'Positivo'
        
    else:
        e_work_set.loc[index,'sentimento'] = 'Negativo'

# %% [markdown]
# Após a contagem de termos positivos e negativos as reviews foram classificadas em sentimento negativo e positivo beasedo apenas na porcentagem de termos positivos e termos negativos.

# %% [markdown]
# ## Separando os dataframes por review

# %%
e_set_rev_1 = e_work_set[e_work_set['review_score'] == 1].reset_index(drop = True)
e_set_rev_2 = e_work_set[e_work_set['review_score'] == 2].reset_index(drop = True)
e_set_rev_3 = e_work_set[e_work_set['review_score'] == 3].reset_index(drop = True)
e_set_rev_4 = e_work_set[e_work_set['review_score'] == 4].reset_index(drop = True)
e_set_rev_5 = e_work_set[e_work_set['review_score'] == 5].reset_index(drop = True)
e_set_rev_1.head()
# Out:
#    order_products_value  review_score  \
# 0                134.90             1
# 1                329.99             1
# 2                251.90             1
# 3                979.00             1
# 4                 62.70             1
#
#                               review_comment_message  \
# 0       o correio ainda não fez a entrega to furioso
# 1  não recebi o meu produto e nem fui avisada da ...
# 2  comprei um produto e recebi outro e inferior g...
# 3  não comprem só vai dar dor de cabeça o produto...
# 4  comprei 2 produtos iguais porém em cores difer...
#
#                                       review_tratada  \
# 0             correio ainda fazer entrega to furioso
# 1  receber produto ser avisar faltar item loja en...
# 2  comprar produto receber outro inferior gostar ...
# 3    comprar s ir dar dor cabea produto nunca chegar
# 4  comprar 2 produto igual porm cor diferente che...
#
#                                             pos_tags  nr_tk_positivos  \
# 0            art n adv pron-pers v-fin art n adj adj              0.0
# 1  pron-pers v-fin art pron-det n conj-c adv v-fi...              3.0
# 2  v-fin art n conj-c v-fin pron-det conj-c adj v...              1.0
# 3  pron-pers v-fin pron-pers v-fin v-inf n prp n ...              1.0
# 4  v-fin num n adj n prp n adj v-fin prp pron-det...              0.0
#
#    porcent_tk_positivos  nr_tk_negativos  porcent_tk_negativos sentimento
# 0              0.000000              1.0              0.166667   Negativo
# 1              0.150000              2.0              0.100000   Positivo
# 2              0.071429              1.0              0.071429     Neutro
# 3              0.111111              1.0              0.111111     Neutro
# 4              0.000000              0.0              0.000000     Neutro

# %%
df = pd.DataFrame()
df['sent_1'] = e_set_rev_1['sentimento'].value_counts()
df['sent_2'] = e_set_rev_2['sentimento'].value_counts()
df['sent_3'] = e_set_rev_3['sentimento'].value_counts()
df['sent_4'] = e_set_rev_4['sentimento'].value_counts()
df['sent_5'] = e_set_rev_5['sentimento'].value_counts()

df.head()
# Out:
#           sent_1  sent_2  sent_3  sent_4  sent_5
# Neutro      3226     741    1119    1693    5194
# Negativo    3223     766    1053     721     875
# Positivo    2851     846    1794    3687   14686

# %%
eval_df_1 = e_set_rev_1[e_set_rev_1['sentimento'] == 'Positivo']
# eval_df_1.head(len(eval_df_1))
# Out:
#       order_products_value  review_score  \
# 1                   329.99             1
# 12                  113.00             1
# 13                   89.90             1
# 16                   40.00             1
# 22                   69.80             1
# 25                  371.70             1
# 27                   65.80             1
# 37                   46.90             1
# 42                   19.90             1
# 43                  239.99             1
# 46                   65.80             1
# 49                  119.99             1
# 52                   53.90             1
# 58                   26.00             1
# 59                  175.00             1
# 65                   74.50             1
# 67                   69.90             1
# 68                   69.90             1
# 69                  119.80             1
# 74                  199.99             1
# 88                   74.90             1
# 110                  18.90             1
# 120                 139.98             1
# 124                  43.89             1
# 126                 881.64             1
# 129                  69.90             1
# 131                  99.99             1
# 133                  59.90             1
# 134                  89.00             1
# 135                  19.90             1
# ...                    ...           ...
# 9229                159.99             1
# 9232                199.00             1
# 9233                 54.55             1
# 9235                 34.50             1
# 9236                 55.00             1
# 9238                161.60             1
# 9242                205.80             1
# 9243                119.99             1
# 9244                260.00             1
# 9246                 99.90             1
# 9247                 69.00             1
# 9254                 79.90             1
# 9256                 99.00             1
# 9258                 63.90             1
# 9265                199.90             1
# 9267                 19.99             1
# 9268                139.94             1
# 9269                 17.99             1
# 9271                139.99             1
# 9274                117.60             1
# 9275                159.90             1
# 9278                190.00             1
# 9279                 35.00             1
# 9281                 50.00             1
# 9282                 51.00             1
# 9291                145.00             1
# 9293                597.00             1
# 9298                 49.80             1
# 9300                 34.90             1
# 9302                 79.00             1
#
#                                  review_comment_message  \
# 1     não recebi o meu produto e nem fui avisada da ...
# 12    não foi entregue o produto que comprei enviara...
# 13    devolvi as toalhas porque não foi o que espera...
# 16    bom dia o lustre anunciado era azul claro foi ...
# 22    só recebi um item o pedido foi feito e peguei ...
# 25    na foto do site consta o produto com 120 cápsu...
# 27    nada a opinar que não seja o fato de ter pago ...
# 37    não recomendo essa loja pra ninguém comprei o ...
# 42    não gostei do produto não funciona como aparec...
# 43    olá queria informar que o produto não foi entr...
# 46    anunciam um artigo e te entregam outro inefici...
# 49    não recebi o produto a entrega seria ate dia 3...
# 52    comprei um simples pendente meia lua no site d...
# 58    eletrobomba não encaixou corretamente na minha...
# 59    valor do produto no site 175 00 mais frete de ...
# 65    até agora não recebi o que é uma pena porque t...
# 67    gostaria de lembrar que esse pedido eu tinha c...
# 68    bom dia ainda não recebi meu produto ainda sen...
# 69    hoje dia 02 08 2017 quarta feira informo que a...
# 74    foram compradas duas cadeiras uma azul e outra...
# 88    foram compradas 2 cortinas de 6m e 3m e foi en...
# 110   não compro mais pois só veio uma capinha pro c...
# 120   não recomendo além da demora para entregar che...
# 124   preciso saber se vai chegar ou não pois ja foi...
# 126   boa tarde os produtos foram entregues ontem em...
# 129   no ato da comprar pelo televendas a atendente ...
# 131   produto não foi entregue não foi enviada nota ...
# 133   comprei um quadro é um adesivo de parede por m...
# 134   pedi o estorno da compra e até agora nada de e...
# 135   já havia solicitado o cancelamento mas mesmo a...
# ...                                                 ...
# 9229  apenas uma reclamação paguei o frete para rece...
# 9232  quase um mês de espera e nada do produto na mi...
# 9233  o produto na imagem da visão maior e qdo receb...
# 9235                                                bom
# 9236                                 por favor reenviar
# 9238  tem mal atendimento voltado para reclamações o...
# 9242  comprei duas mochilas e recebi somente um prod...
# 9243  não recebi o produto não sei o que aconteceu e...
# 9244  os cartuchos não funcionaram na minha impresso...
# 9246  o targaryen já foi uma boa loja estou a duas s...
# 9247                               não é bom o material
# 9254  prezados não recebemos nada preciso saber quem...
# 9256  estive sexta feira na loja e o produto não foi...
# 9258  mais um vez veio faltando o item kit flor arti...
# 9265                   meus pedidos não foram entregues
# 9267  produto fora de prazo não deram satisfação alg...
# 9268  olá minha queixa é a não entrega na residência...
# 9269               não posso avaliar não sei oque houve
# 9271  nao posso avaliar o produto nao foi entregue p...
# 9274  apesar do produto ter chegado no prazo as medi...
# 9275  veio avariado e já pedi a troca ou cancelament...
# 9278  no dia 30 03 2017 foi entregue apenas 1 um pot...
# 9279                   não recomendo comprar nesse site
# 9281  seria muito bom mas como eu recebi o produto c...
# 9282  tonner compativel instala ok na impressora mas...
# 9291  adquiri dois produtos e entregaram apenas um s...
# 9293  até o presente momento o meu pedido não foi en...
# 9298  não recebi o pedido todo vieram 4 pacotes cada...
# 9300  pedi duas pulseias e só recebi uma a pulseira ...
# 9302               o produto não foi entregue indignada
#
#                                          review_tratada  \
# 1     receber produto ser avisar faltar item loja en...
# 12    ser entregar produto comprar enviar outro prod...
# 13    devolver toalha porque ser esperar relao quali...
# 16    bom dia lustre anunciar ser azul claro ser ent...
# 22    s receber item pedido ser fazer peguei 2 item ...
# 25    foto site constar produto 120 cpsula pote rece...
# 27    nada opinar ser fato ter pagar ter receber pro...
# 37    recomendar loja pra ningum comprar presente fi...
# 42         gostar produto funcionar aparecer propaganda
# 43              ol querer informar produto ser entregar
# 46    anunciar artigo entregar outro ineficincia log...
# 49      receber produto entrega ser atar dia 30 11 2016
# 52    comprar simples pendente meio lua site lannist...
# 58    eletrobombar encaixou correto mquinar ob gosta...
# 59    valor produto site 175 00 frete 12 73 emitir n...
# 65    at agora receber pena porque todo outro produt...
# 67    gostar lembrar pedido ter cancelar ato compra ...
# 68    bom dia ainda receber produto ainda ser assim ...
# 69    hoje dia 02 08 2017 quarta feira informo ainda...
# 74    ser comprar dois cadeira azul outro verde ser ...
# 88    ser comprar 2 cortina 6m 3m ser entregar apena...
# 110   comprar pois s vir capa pro celular cor rosar ...
# 120   recomendar alm demora entregar chegar apenas c...
# 124   precisar saber ir chegar pois jo ser pagar que...
# 126   bom tarde produto ser entregar ontem pleno dom...
# 129   ato comprar televendas atendente colocar produ...
# 131   produto ser entregar ser enviar nota fiscal te...
# 133   comprar quadro adesivo parede motivo esclarece...
# 134   pedir estorno compra at agora nada estorno zer...
# 135   j haver solicitar cancelamento assim produto s...
# ...                                                 ...
# 9229  apenas reclamao pagar frete receber residncer ...
# 9232  quase m espera nada produto opiniar vendedor n...
# 9233  produto imagem viso grande qdo receber ver cor...
# 9235                                                bom
# 9236                                     favor reenviar
# 9238  ter mal atendimento voltar reclamae produto en...
# 9242  comprar dois mochila receber somente produto v...
# 9243  receber produto saber acontecer ningum dar sat...
# 9244  cartucho funcionar imprimir impressora reconhe...
# 9246  targaryen j ser bom loja estar dois semana ten...
# 9247                                       bom material
# 9254          prezar receber nada preciso saber receber
# 9256  estar sexta feira loja produto ser entregar de...
# 9258  vez vir faltar item kit flor artificial orqude...
# 9265                                pedido ser entregar
# 9267  produto prazo dar satisfao algum compra realiz...
# 9268  ol queixa entregar residncia ter buscar correi...
# 9269                     poder avaliar saber oque haver
# 9271  naar poder avaliar produto nao ser entregar pr...
# 9274  apesar produto ter chegar prazo medida adequar...
# 9275  vir avariar j pedir troca cancelamento poder a...
# 9278  dia 30 03 2017 ser entregar apenas 1 pote prod...
# 9279                      recomendar comprar nesse site
# 9281  ser bom receber produto defeito gostar ser bem...
# 9282  tonner compativel instalar ok impressora sair ...
# 9291  adquirir dois produto entregar apenas resposta...
# 9293  at presente momento pedido ser entregar segund...
# 9298  receber pedido todo vir 4 pacote cada pea oito...
# 9300  pedir dois pulseia s receber pulseira masculin...
# 9302                      produto ser entregar indignar
#
#                                                pos_tags  nr_tk_positivos  \
# 1     pron-pers v-fin art pron-det n conj-c adv v-fi...              3.0
# 12    pron-pers v-fin v-pcp art n pron-indp v-fin v-...              2.0
# 13    v-fin art n conj-s pron-pers v-fin pron-det pr...              1.0
# 16    adj n art n v-pcp v-fin adj adv v-fin v-pcp ad...              5.0
# 22    n v-fin art n art n v-fin v-pcp conj-c adj prp...              2.0
# 25    pron-pers n adj n v-fin art n prp num n art n ...              1.0
# 27    pron-indp pron-det n pron-indp pron-pers v-fin...              3.0
# 37    pron-pers v-fin pron-det n prp n v-fin art n a...              2.0
# 42    pron-pers v-fin adj n pron-pers v-fin adv v-fi...              3.0
# 43    adj v-fin v-inf conj-s art n pron-pers v-fin v...              1.0
# 46    v-fin art n conj-c pron-pers v-fin pron-det n ...              3.0
# 49    pron-pers v-fin art n art n v-fin v-fin n num ...              1.0
# 52    v-fin art adj adj adj n pron-pers n adv v-inf ...              2.0
# 58    v-fin pron-pers adv adv pron-pers pron-det v-f...              2.0
# 59    n adj n pron-pers n num num adv n prp num num ...              3.0
# 65    pron-indp adv pron-pers v-fin pron-det pron-in...              2.0
# 67    v-fin prp v-inf conj-s pron-det n pron-pers v-...              2.0
# 68    adj n adv pron-pers v-fin pron-det n adv v-ger...              2.0
# 69    adv n num n num n n adj pron-indp adv pron-per...              3.0
# 74    v-fin v-pcp num n art adj conj-c pron-det adj ...              2.0
# 88    v-fin v-pcp num adj prp num conj-c num conj-c ...              2.0
# 110   pron-pers v-fin adv conj-s pron-pers v-fin art...              2.0
# 120   pron-pers v-fin v-fin pron-pers n prp v-inf v-...              5.0
# 124   v-fin v-inf conj-s v-fin v-inf conj-c pron-per...              2.0
# 126   adj n art n v-fin v-pcp adv prp adj n pron-per...              2.0
# 129   pron-pers n adj v-inf n adv pron-det pron-indp...              2.0
# 131   n pron-pers v-fin v-pcp pron-pers v-fin v-pcp ...              3.0
# 133   v-fin art n art adj prp n prp n pron-pers v-pc...              3.0
# 134   v-fin art adj adj n conj-c n adv pron-indp prp...              1.0
# 135   n v-fin v-pcp art n conj-c adv adv art n v-fin...              3.0
# ...                                                 ...              ...
# 9229  adv art n v-fin art n prp v-inf pron-pers pron...              2.0
# 9232  adv num n prp n conj-c adv adj n pron-pers pro...              3.0
# 9233  art n pron-pers n adj adj adj conj-c n v-fin v...              2.0
# 9235                                                adj              1.0
# 9236                                          prp n adj              1.0
# 9238  v-fin adv n v-pcp prp n art n art pron-det pro...              2.0
# 9242  v-fin num n conj-c v-fin adv art n art n n adj...              1.0
# 9243  pron-pers v-fin art n pron-pers v-fin pron-det...              3.0
# 9244  art n pron-pers v-fin pron-pers pron-det v-pcp...              2.0
# 9246  art n n v-fin art adj n v-fin prp num n v-ger ...              6.0
# 9247                                pron-pers adj art n              1.0
# 9254  v-ger pron-pers v-fin adv adj v-inf pron-indp ...              2.0
# 9256  v-fin adj n pron-pers n conj-c art n pron-pers...              3.0
# 9258  pron-det art n v-fin v-ger art n n n adj adj n...              3.0
# 9265                   pron-det n pron-pers v-fin v-pcp              1.0
# 9267  n adv prp n pron-pers v-fin adj pron-det n v-p...              3.0
# 9268  adj pron-det n prp pron-pers v-fin pron-pers n...              3.0
# 9269      pron-pers v-fin v-inf pron-pers v-fin n v-fin              1.0
# 9271  v-fin v-fin v-inf art n pron-pers v-fin v-pcp ...              2.0
# 9274  adv adj n v-inf v-pcp pron-pers n art n pron-p...              3.0
# 9275  v-fin v-pcp conj-c n v-fin art n conj-c n v-fi...              1.0
# 9278  pron-pers n num num n v-fin v-pcp adv num num ...              3.0
# 9279                          pron-pers v-fin v-inf n n              1.0
# 9281  v-fin adv adj conj-c adv pron-pers v-fin art n...              6.0
# 9282  v-inf adj v-fin prop pron-pers n conj-c v-fin ...              3.0
# 9291  v-fin num n conj-c v-fin adv num prp n prp adv...              1.0
# 9293  n art n n art pron-det n pron-pers v-fin v-pcp...              2.0
# 9298  pron-pers v-fin art n adv v-fin num n pron-det...              1.0
# 9300  v-fin num n conj-c n v-fin num prp n adj prp c...              1.0
# 9302                  art n pron-pers v-fin v-pcp v-pcp              1.0
#
#       porcent_tk_positivos  nr_tk_negativos  porcent_tk_negativos sentimento
# 1                 0.150000              2.0              0.100000   Positivo
# 12                0.100000              1.0              0.050000   Positivo
# 13                0.055556              0.0              0.000000   Positivo
# 16                0.454545              2.0              0.181818   Positivo
# 22                0.125000              0.0              0.000000   Positivo
# 25                0.058824              0.0              0.000000   Positivo
# 27                0.150000              1.0              0.050000   Positivo
# 37                0.080000              1.0              0.040000   Positivo
# 42                0.600000              1.0              0.200000   Positivo
# 43                0.166667              0.0              0.000000   Positivo
# 46                0.166667              2.0              0.111111   Positivo
# 49                0.111111              0.0              0.000000   Positivo
# 52                0.080000              0.0              0.000000   Positivo
# 58                0.285714              0.0              0.000000   Positivo
# 59                0.176471              2.0              0.117647   Positivo
# 65                0.181818              1.0              0.090909   Positivo
# 67                0.100000              1.0              0.050000   Positivo
# 68                0.200000              0.0              0.000000   Positivo
# 69                0.100000              0.0              0.000000   Positivo
# 74                0.166667              0.0              0.000000   Positivo
# 88                0.133333              0.0              0.000000   Positivo
# 110               0.111111              0.0              0.000000   Positivo
# 120               0.250000              1.0              0.050000   Positivo
# 124               0.200000              0.0              0.000000   Positivo
# 126               0.111111              1.0              0.055556   Positivo
# 129               0.105263              0.0              0.000000   Positivo
# 131               0.300000              1.0              0.100000   Positivo
# 133               0.230769              0.0              0.000000   Positivo
# 134               0.111111              0.0              0.000000   Positivo
# 135               0.200000              0.0              0.000000   Positivo
# ...                    ...              ...                   ...        ...
# 9229              0.111111              0.0              0.000000   Positivo
# 9232              0.166667              0.0              0.000000   Positivo
# 9233              0.153846              1.0              0.076923   Positivo
# 9235              1.000000              0.0              0.000000   Positivo
# 9236              0.500000              0.0              0.000000   Positivo
# 9238              0.105263              1.0              0.052632   Positivo
# 9242              0.062500              0.0              0.000000   Positivo
# 9243              0.272727              0.0              0.000000   Positivo
# 9244              0.333333              0.0              0.000000   Positivo
# 9246              0.285714              2.0              0.095238   Positivo
# 9247              0.500000              0.0              0.000000   Positivo
# 9254              0.333333              0.0              0.000000   Positivo
# 9256              0.230769              2.0              0.153846   Positivo
# 9258              0.176471              2.0              0.117647   Positivo
# 9265              0.333333              0.0              0.000000   Positivo
# 9267              0.150000              0.0              0.000000   Positivo
# 9268              0.176471              1.0              0.058824   Positivo
# 9269              0.200000              0.0              0.000000   Positivo
# 9271              0.222222              1.0              0.111111   Positivo
# 9274              0.150000              1.0              0.050000   Positivo
# 9275              0.111111              0.0              0.000000   Positivo
# 9278              0.120000              0.0              0.000000   Positivo
# 9279              0.250000              0.0              0.000000   Positivo
# 9281              0.545455              1.0              0.090909   Positivo
# 9282              0.230769              1.0              0.076923   Positivo
# 9291              0.111111              0.0              0.000000   Positivo
# 9293              0.111111              1.0              0.055556   Positivo
# 9298              0.062500              0.0              0.000000   Positivo
# 9300              0.047619              0.0              0.000000   Positivo
# 9302              0.250000              0.0              0.000000   Positivo
#
# [2851 rows x 10 columns]

# %%
eval_df_5 = e_set_rev_5[e_set_rev_5['sentimento'] == 'Negativo']
eval_df_5.head(len(eval_df_5))
# Out:
#        order_products_value  review_score  \
# 17                   188.00             5
# 35                    99.00             5
# 41                    21.90             5
# 53                   422.00             5
# 79                    79.90             5
# 94                   119.80             5
# 213                   73.00             5
# 268                   49.90             5
# 273                   54.00             5
# 277                  139.00             5
# 326                 1699.99             5
# 380                   29.99             5
# 424                   59.00             5
# 434                   49.90             5
# 456                  699.00             5
# 459                  229.99             5
# 461                   89.99             5
# 468                  189.00             5
# 469                  143.00             5
# 471                  467.40             5
# 479                   29.90             5
# 531                   55.00             5
# 546                   84.99             5
# 548                   78.00             5
# 556                   57.50             5
# 559                  159.90             5
# 566                   59.99             5
# 578                   54.90             5
# 612                   29.90             5
# 617                  229.90             5
# ...                     ...           ...
# 20211                149.00             5
# 20239                 94.60             5
# 20258                299.99             5
# 20265                 39.00             5
# 20283                 49.90             5
# 20302                279.80             5
# 20306                 29.90             5
# 20343                 14.90             5
# 20350                 32.90             5
# 20365                113.99             5
# 20431                 18.89             5
# 20433                 37.99             5
# 20435                 16.90             5
# 20448                149.90             5
# 20476                 27.90             5
# 20511                 49.00             5
# 20521                 39.99             5
# 20522                690.00             5
# 20559               3599.00             5
# 20583                 32.64             5
# 20603                 89.90             5
# 20624                109.99             5
# 20653                 69.00             5
# 20670                 49.09             5
# 20676                 10.99             5
# 20680                549.10             5
# 20711                307.30             5
# 20725                 45.90             5
# 20738                 88.00             5
# 20748                 27.30             5
#
#                                   review_comment_message  \
# 17     já fiz várias compras pelo stark nuca tive pro...
# 35     o produto comprado embora diga que é específic...
# 41                  nao abri ainda pq nao vou usar agora
# 53        produto conforme anuncio chegou antes do prazo
# 79     o produto chegou até antes do prazo estou sati...
# 94     olá meu produto nao recebi ainda mais sempre r...
# 213    a caixa é linda as divisórias internas podem s...
# 268    incrível que pela primeira vez que demora pra ...
# 273                           produto conforme anunciado
# 277    ótimo produto empresa cumpre o anunciado pneus...
# 326                     produto corresponde ao anunciado
# 380    as correntes são boas e o material também a co...
# 424    a princípio fiquei com medo não pela loja mas ...
# 434    ótima capa para meu banjo cx larga alças de mã...
# 456                                          sem queixas
# 459    o produto chegou antes do prazo e tal qual est...
# 461                                        sem problemas
# 468              dentro do prazo e a qualidade rotineira
# 469    produto de ótima qualidade tive problemas com ...
# 471    recebemos os produtos e já estão em operação o...
# 479    já compro algum tempo nessa loja e não tenho n...
# 531    entregue antes msm do previsto relogio lindo s...
# 546    produto entregue antes dl tempo determinado e ...
# 548    peço desculpas pela avaliação anterior onde in...
# 556    chegou um pouco de atraso mas muito lindo amei...
# 559    eu recebi produto mais a cor veio errada eu pe...
# 566    o fato de retirar nos correios não deveria pag...
# 578    entregue no prazo e a embalagem estava um capr...
# 612    adorei ficou menor que o banco do carro mas a ...
# 617    ótima compra para quem tem pouco espaço pra se...
# ...                                                  ...
# 20211  entrega efetuada antes do prazo 3 compra sem p...
# 20239  nao tenho nada a reclamar tudo que comprei che...
# 20258    envio muito rápido e chegou muito rápido também
# 20265                veio com a alça do relógio quebrada
# 20283  vale a pena comprar o produto foi igual o que ...
# 20302  o produto é original embora a entrega tenha fi...
# 20306                 envio rápido produto como descrito
# 20343  compro a muito tempo nunca tive problemas hoje...
# 20350  entrega rápida profuto devidamente embalado pr...
# 20365                      parabens chegou em tempo abel
# 20431       produto entregue conforme anunciado obrigado
# 20433                         pena que o prazo foi longo
# 20435                             podem comprar sem medo
# 20448                                        vale a pena
# 20476  meu produto so não esta nas minhas mãos por er...
# 20511    como sempre não tive problemas com as lannister
# 20521      sempre compro nesse site nunca tive problemas
# 20522                                   ainda nao testei
# 20559  veio faltando os brindes mais entrei em contat...
# 20583  produto estava no site c o prazo de 8 dias úte...
# 20603                      parabens chegou em tempo abel
# 20624  fiquei dias sem uma posição do status do produ...
# 20653  houve um erro de numeracao apenas nada grave q...
# 20670        pedido entregue sem restrições e sem atraso
# 20676  já recebi só que o lg k10 esta demorando estou...
# 20680  chegou antes do prazo é como anunciado ótimo p...
# 20711                           não troco por outra loja
# 20725                              chegou em pouco tempo
# 20738  ainda não testei o produto mas chegou no prazo...
# 20748  recebi o produto dentro do prazo veio embalado...
#
#                                           review_tratada  \
# 17           j fazer vria compra stark nuca ter problema
# 35     produto comprar embora dizer especfiquir celul...
# 41                  naar abri ainda pq nao ir usar agora
# 53          produto conforme anunciar chegar antes prazo
# 79     produto chegar at antes prazo estar satisfeiti...
# 94      ol produto nao receber ainda sempre receber tudo
# 213    caixa lindar divisria interno poder ser retira...
# 268    incrvel pelar primeira vez demorar pra entrega...
# 273                            produto conforme anunciar
# 277    timo produto empresa cumprir anunciar pneu mag...
# 326                        produto corresponder anunciar
# 380    corrente bom material tambm corrente grosso se...
# 424    princpio ficar medo pelar loja cuidado correio...
# 434          tima capa banjo cx largo ala mo costa tambm
# 456                                               queixa
# 459          produto chegar antes prazo tal estar anncio
# 461                                             problema
# 468                     dentro prazo qualidade rotineiro
# 469    produto tima qualidade ter problema correio nd...
# 471               receber produto j estar operao obrigar
# 479    j compro algum tempo nessar loja ter nada recl...
# 531    entregar antes msm prever relogio lindar nenhu...
# 546    produto entregar antes dl tempo determinar per...
# 548    pear desculpa avaliao anterior onde infomeiuqu...
# 556         chegar pouco atraso lindar ameiii valer pena
# 559    receber produto cor vir errar pedir preto pret...
# 566    fato retirar correio dever pagar frete pois pa...
# 578      entregar prazo embalagem estar capricho obrigar
# 612    adorar ficar pequeno banco carro culpa medir e...
# 617         tima compra ter pouco espaar pra secar roupa
# ...                                                  ...
# 20211     entregar efetuar antes prazo 3 compra problema
# 20239  naar ter nada reclamar tudo comprar chegar per...
# 20258                      envio rpido chegar rper tambm
# 20265                             vir ala relgio quebrar
# 20283     valer pena comprar produto igual escolher site
# 20302  produto original embora entrega ter ficar conf...
# 20306                      envio rpido produto descrever
# 20343  comprar tempo nunca ter problema hoje melhorar...
# 20350  entregar rpidar profuto devidamente embalar pr...
# 20365                          parabem chegar tempo abel
# 20431         produto entregar conforme anunciar obrigar
# 20433                               pena prazo ser longo
# 20435                                 poder comprar medo
# 20448                                         valer pena
# 20476                                   produto mos erro
# 20511                      sempre ter problema lannister
# 20521          sempre compro ner site nunca ter problema
# 20522                                   ainda nao testar
# 20559  vir faltar brinde entrar contato loja ea infor...
# 20583  produto estar site c prazo 8 dia tel pagar dia...
# 20603                          parabem chegar tempo abel
# 20624  ficar dia posio status produto informar algo e...
# 20653  haver erro numeracao apenas nada grave vir des...
# 20670                     pedido entregar restrie atraso
# 20676  j receber s lg k10 demorando estar espera pois...
# 20680           chegar antes prazo anunciar timo produto
# 20711                                   troco outro loja
# 20725                                 chegar pouco tempo
# 20738  ainda testar produto chegar prazo estipular pa...
# 20748  receber produto dentro prazo vir embalar ter d...
#
#                                                 pos_tags  nr_tk_positivos  \
# 17                       n v-fin adj n adj n adj v-fin n              0.0
# 35     art n v-pcp conj-s v-fin conj-s v-inf prp art ...              1.0
# 41                   v-fin n adv v-fin n v-fin v-inf adv              0.0
# 53                           n adv v-fin v-fin adv adj n              0.0
# 79     art n v-fin n adv adj n v-fin adv v-pcp v-fin ...              0.0
# 94     adj pron-det n n v-fin adv adv adv v-fin pron-...              0.0
# 213    art n v-pcp art n adj v-fin v-inf v-pcp n v-fi...              2.0
# 268    n pron-indp v-fin adj n pron-indp v-fin prp n ...              0.0
# 273                                          n adv v-pcp              0.0
# 277    adj n n v-fin art v-pcp n v-fin num num conj-c...              0.0
# 326                                    n v-fin prp v-pcp              0.0
# 380    art n adj adj conj-c art n n prp n adj v-ger p...              1.0
# 424    art adj v-fin prp n pron-pers v-fin n conj-c n...              1.0
# 434    adj n prp pron-det n adj adj n prp adj conj-c ...              0.0
# 456                                                prp n              0.0
# 459    art n v-fin adv adj n conj-c pron-det pron-det...              0.0
# 461                                                prp n              0.0
# 468                           adv adj n conj-c art n adj              0.0
# 469          n prp adj n v-fin n prp n adv adj prp art n              0.0
# 471               v-fin art n conj-c n v-pcp prp n v-pcp              0.0
# 479    n adj pron-det n v-fin n conj-c pron-pers v-fi...              0.0
# 531    v-pcp adv v-fin adj v-pcp adv v-ger prp pron-d...              0.0
# 546           n v-pcp adv adj n v-pcp conj-c prp v-pcp n              0.0
# 548    v-fin n n adj adj adv adv adv pron-pers v-fin ...              0.0
# 556    v-fin art pron-det prp n conj-c adv v-ger adv ...              0.0
# 559    pron-pers v-fin n adv art n v-fin v-pcp pron-p...              0.0
# 566    art n prp v-inf pron-pers n pron-pers v-fin v-...              0.0
# 578     v-pcp pron-pers n conj-c art n v-fin art n v-pcp              0.0
# 612    v-fin v-fin adj conj-s art n adj n conj-c art ...              1.0
# 617    adj n prp pron-indp v-fin pron-det v-fin prp v...              0.0
# ...                                                  ...              ...
# 20211                  v-fin v-pcp adv adj n num n prp n              0.0
# 20239  v-fin v-fin adv prp v-inf pron-indp pron-indp ...              0.0
# 20258            n adv adj conj-c v-fin pron-det v-pcp n              0.0
# 20265                        v-fin prp art n adj n v-pcp              0.0
# 20283  v-fin art n v-inf art n adv adj pron-indp pron...              0.0
# 20302  art n adj adv art n v-fin v-pcp adj n conj-s p...              1.0
# 20306                                  n adj n adv v-pcp              0.0
# 20343  v-fin prp pron-det n adv v-fin n adv v-fin adv...              1.0
# 20350      v-fin v-pcp n adv v-pcp n prop conj-c v-fin n              0.0
# 20365                                    n v-fin prp n n              0.0
# 20431                            n v-pcp adv v-pcp v-pcp              0.0
# 20433                        n pron-indp art n v-fin adj              1.0
# 20435                                  v-fin v-inf prp n              0.0
# 20448                                        v-fin art n              0.0
# 20476  pron-det n prop pron-pers pron-det pron-pers p...              0.0
# 20511                adv adv pron-pers v-fin n prp art n              0.0
# 20521                        adv adj v-fin n adv v-fin n              0.0
# 20522                                adv pron-pers v-fin              0.0
# 20559  v-fin v-ger art n adv v-fin prp n prp art n ad...              0.0
# 20583  n v-fin pron-pers n num art n prp num n adj v-...              1.0
# 20603                                    n v-fin prp n n              0.0
# 20624  v-fin n prp art n adj n adj n v-ger conj-s pro...              0.0
# 20653  v-fin art n prp n adv adv adj pron-indp v-fin ...              1.0
# 20670                         n v-pcp prp n conj-c prp n              0.0
# 20676  n v-fin n pron-indp pron-pers v-fin prp pron-d...              0.0
# 20680                      v-fin adv adj n prp v-pcp n n              0.0
# 20711                         pron-pers n prp pron-det n              0.0
# 20725                               v-fin prp pron-det n              0.0
# 20738  adv pron-pers v-fin art n conj-c v-fin pron-pe...              0.0
# 20748  v-fin art n adv adj n v-fin v-pcp conj-c pron-...              0.0
#
#        porcent_tk_positivos  nr_tk_negativos  porcent_tk_negativos sentimento
# 17                 0.000000              1.0              0.125000   Negativo
# 35                 0.058824              2.0              0.117647   Negativo
# 41                 0.000000              1.0              0.125000   Negativo
# 53                 0.000000              1.0              0.166667   Negativo
# 79                 0.000000              1.0              0.062500   Negativo
# 94                 0.000000              1.0              0.125000   Negativo
# 213                0.086957              3.0              0.130435   Negativo
# 268                0.000000              1.0              0.066667   Negativo
# 273                0.000000              1.0              0.333333   Negativo
# 277                0.000000              1.0              0.090909   Negativo
# 326                0.000000              1.0              0.333333   Negativo
# 380                0.111111              3.0              0.333333   Negativo
# 424                0.058824              3.0              0.176471   Negativo
# 434                0.000000              1.0              0.111111   Negativo
# 456                0.000000              1.0              1.000000   Negativo
# 459                0.000000              1.0              0.142857   Negativo
# 461                0.000000              1.0              1.000000   Negativo
# 468                0.000000              1.0              0.250000   Negativo
# 469                0.000000              1.0              0.125000   Negativo
# 471                0.000000              1.0              0.166667   Negativo
# 479                0.000000              2.0              0.222222   Negativo
# 531                0.000000              1.0              0.125000   Negativo
# 546                0.000000              1.0              0.125000   Negativo
# 548                0.000000              2.0              0.142857   Negativo
# 556                0.000000              2.0              0.285714   Negativo
# 559                0.000000              3.0              0.150000   Negativo
# 566                0.000000              2.0              0.125000   Negativo
# 578                0.000000              1.0              0.166667   Negativo
# 612                0.125000              4.0              0.500000   Negativo
# 617                0.000000              1.0              0.125000   Negativo
# ...                     ...              ...                   ...        ...
# 20211              0.000000              1.0              0.142857   Negativo
# 20239              0.000000              1.0              0.111111   Negativo
# 20258              0.000000              1.0              0.200000   Negativo
# 20265              0.000000              1.0              0.250000   Negativo
# 20283              0.000000              1.0              0.142857   Negativo
# 20302              0.055556              2.0              0.111111   Negativo
# 20306              0.000000              1.0              0.250000   Negativo
# 20343              0.090909              3.0              0.272727   Negativo
# 20350              0.000000              1.0              0.111111   Negativo
# 20365              0.000000              1.0              0.250000   Negativo
# 20431              0.000000              1.0              0.200000   Negativo
# 20433              0.250000              2.0              0.500000   Negativo
# 20435              0.000000              1.0              0.333333   Negativo
# 20448              0.000000              1.0              0.500000   Negativo
# 20476              0.000000              1.0              0.333333   Negativo
# 20511              0.000000              1.0              0.250000   Negativo
# 20521              0.000000              1.0              0.142857   Negativo
# 20522              0.000000              1.0              0.333333   Negativo
# 20559              0.000000              2.0              0.153846   Negativo
# 20583              0.041667              2.0              0.083333   Negativo
# 20603              0.000000              1.0              0.250000   Negativo
# 20624              0.000000              1.0              0.100000   Negativo
# 20653              0.076923              2.0              0.153846   Negativo
# 20670              0.000000              1.0              0.250000   Negativo
# 20676              0.000000              1.0              0.076923   Negativo
# 20680              0.000000              1.0              0.166667   Negativo
# 20711              0.000000              1.0              0.333333   Negativo
# 20725              0.000000              1.0              0.333333   Negativo
# 20738              0.000000              1.0              0.125000   Negativo
# 20748              0.000000              2.0              0.100000   Negativo
#
# [875 rows x 10 columns]

# %% [markdown]
# Analisando as reviews consideradas com sentimento positivo e com nota baixa vemos que algumas reviews analisam o histórico do desempenho da loja como positivo, mas relatam problemas atuais com o pedido atual.
#
# Além disso, vemos algumas palavras que são podem ser consideradas positivas, mas que são alteradas pelo contexto, por exemplo "não recomendo".

# %%
eval_df_1['review_comment_message'][9246]
# Out:
# 'o targaryen já foi uma boa loja estou a duas semanas tentando falar com eles sobre um produto fun kitchen que deu defeito para eu procurar uma autorizada e não consigo eu não recomendo essa loja'

# %% [markdown]
# Vê-se uma situação semelhante nas reviews de nota alta e sentimento predominantemente negativo. Há o uso de palavras que são consideradas negativas como "problema", mas tem seu sentido alterado pelo contexto.
#
# Há também o uso de advérbios de intensidade, que são contados como positivos, mas que podem amplificar um sentimento negativo

# %%
eval_df_5['review_comment_message'][20343]
# Out:
# 'compro a muito tempo nunca tive problemas hoje melhorou mais ainda parabéns vocês são 10'

# %% [markdown]
# ### Encontrar as n palavras mais frequentes
#
# Foi feita uma função para se obter as palavras mais frequentes em um conjunto de reviews. No caso as reviews estão agrupadas pela nota dada ao produto.

# %%
def get_top_n_words(dataframe, n=None):
    
    # Encontra as palavras de maior frequência em um corpus e retorna como um par palavra, nº de ocorrências
    
    corpus = []
    for linha in dataframe.itertuples():
        corpus.append(linha[4])
    
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key = lambda x: x[1], reverse=True)

    return words_freq[:n]

# %%
top_w_1 = pd.DataFrame(get_top_n_words(e_set_rev_1,n = 10),columns = ['Palavra','Frequência'])
top_w_1
# Out:
#     Palavra  Frequência
# 0   produto        5511
# 1   receber        3576
# 2       ser        3170
# 3   comprar        2312
# 4  entregar        2199
# 5       ter        1529
# 6    chegar        1450
# 7       vir        1423
# 8     estar        1255
# 9     ainda        1232

# %%
top_w_2 = pd.DataFrame(get_top_n_words(e_set_rev_2,n = 10),columns = ['Palavra','Frequência'])
top_w_2
# Out:
#     Palavra  Frequência
# 0   produto        1286
# 1       ser         813
# 2   receber         672
# 3       vir         495
# 4  entregar         484
# 5   comprar         470
# 6       ter         386
# 7    chegar         367
# 8     estar         297
# 9     ainda         254

# %%
top_w_3 = pd.DataFrame(get_top_n_words(e_set_rev_3,n = 10),columns = ['Palavra','Frequência'])
top_w_3
# Out:
#     Palavra  Frequência
# 0   produto        1951
# 1       ser        1221
# 2       vir         772
# 3   receber         770
# 4       ter         696
# 5       bom         684
# 6  entregar         652
# 7    chegar         588
# 8   comprar         509
# 9     prazo         502

# %%
top_w_4 = pd.DataFrame(get_top_n_words(e_set_rev_4,n = 10),columns = ['Palavra','Frequência'])
top_w_4
# Out:
#       Palavra  Frequência
# 0     produto        2681
# 1         bom        1518
# 2       prazo        1394
# 3         ser        1147
# 4    entregar        1056
# 5      chegar         940
# 6       antes         762
# 7  recomendar         596
# 8     entrega         587
# 9         vir         581

# %%
top_w_5 = pd.DataFrame(get_top_n_words(e_set_rev_5,n = 10),columns = ['Palavra','Frequência'])
top_w_5
# Out:
#       Palavra  Frequência
# 0     produto        8654
# 1       prazo        5680
# 2       antes        4481
# 3    entregar        4019
# 4         bom        3999
# 5  recomendar        3577
# 6      chegar        3505
# 7         bem        2274
# 8         ser        2234
# 9     entrega        1958

# %% [markdown]
# Analisando as palavras mais frequêntes encontradas em cada agrupamento de reviews vemos que há nos reviews de notas mais altos palavras como "bom", "recomendar","bem" e "antes" estão mais presentes.
#
# Em contrapartida, vemos que o que diferencia as reviews de nota mais baixa é apenas a palavra "ainda", que provavelmente está associada ao fato de o produto não ter sido entregue.
#
# As palavras comuns a todas as reviews referem-se a palavras frequêntes no contexto analisado. Palavras como "produto","prazo","entregar" estaram provavelmente em todas as reviews e não possuem valor de sentimento atrelados a elas.

# %% [markdown]
# # Conclusão
#
# ## Sobre as reviews
#
# Vemos dados interessantes retirados das reviews. Apesar da simplicidade do método, vemos que o número de reviews com sentimento positivo era muito maior para as reviews de nota 5, além de crescerem a partir das reviews de nota 1.
#
# Analisando as médias de tokens para cada grupo de reviews, vemos que os grupos com mais tokens são as reviews de nota 1 e nota 5. Isso nos leva a teorizar que as pessoas escrevem mais quando seus textos possuem sentimentos mais intensos, sejam positivos ou negativos.
#
# ## Sobre os métodos utilizados
#
# Ao final desse trabalho é importante destacar as limitações dos métodos da NLP. Apesar de apresentar resultados satisfatórios, vemos que dificilmente uma análise de sentimento de metodologia tão simples poderia dizer sobre o teor da mensagem. Um exemplo disso é que, não é possível mostrar o uso de alongamentos em uma palavra para demonstrar intensidade de um sentimento, por exemplo, "adoreeeeei".
#
# Para uma análise de sentimentos com maior precisão seria recomendável a utilização de serviços como a inteligência artificial Watson da IBM.
#
# O lematizador também se mostrou um problema. Várias vezes ele considerou as últimas letras de alguma palavra como algum morfema de flexão verbal e criou um verbo inexistente. Isso acarretou uma perda de precisão em todos os outros processos de pré porocessamento utilizados.
