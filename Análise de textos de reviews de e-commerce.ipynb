# %% [markdown]
# # Análise de reviews de produtos usando NLP
#
# O presente trabalho pretende analisar os textos de revisão de produtos da base de dados obtida na plataforma Kaggle. Para isso serão usadas bibliotecas Python de processamento de linguagem natural já conhecidas como Spacy, Sci-kit Learn e.
#
# https://www.kaggle.com/olistbr/brazilian-ecommerce
#
# Objetivos:
# - Encontrar caracaterísticas que distinguam textos de reviews com notas altas e com notas baixas.
# - Analisar textos com análise de sentimentos e identificar textos muito negativos, mas que possuam notas altas.

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
import spacy
from nltk import corpus
import nltk
import re
from unicodedata import normalize
import itertools as it
import numpy as np

# %%
# Definindo a máquina virtual Java para o lematizador e pos-tagger de Stanford
from py4j.java_gateway import JavaGateway

gg = JavaGateway.launch_gateway(classpath="./java/lemmatizerpt.jar;./java/py4j0.10.8.1.jar;./java/stanford-postagger.jar;./java/lemport-0.9.7.jar")

# %%
e_set = pd.read_csv("./brazilian-ecommerce/olist_public_dataset_v2.csv")
e_set.head()
# Out:
#                            order_id order_status  order_products_value  \
# 0  b95df3cef5297e79ef709ba256518f6f    delivered                349.90
# 1  59af46052a799e80e2f0c665c587731d    delivered                 15.00
# 2  a3e6136894621db402a772c6bc72a12a    delivered                238.90
# 3  b675ea5a618922f6e679e30531b8957b    delivered                 29.99
# 4  195a8be6794c487fe6cfbb97b7c61902    delivered                295.99
#
#    order_freight_value  order_items_qty  order_sellers_qty  \
# 0                13.84                1                  1
# 1                15.10                1                  1
# 2                18.00                1                  1
# 3                18.23                1                  1
# 4                47.65                1                  1
#
#      order_purchase_timestamp            order_aproved_at  \
# 0  2017-01-31 17:19:01.000000  2017-02-01 02:41:21.549551
# 1  2017-09-09 19:52:54.000000  2017-09-10 20:03:31.535281
# 2  2017-01-30 17:00:09.000000  2017-01-30 17:31:25.438253
# 3  2018-03-11 18:18:36.000000  2018-03-11 18:30:37.931962
# 4  2017-04-20 08:01:08.000000  2017-04-25 08:05:40.405383
#
#   order_estimated_delivery_date order_delivered_customer_date  \
# 0    2017-03-15 00:00:00.000000    2017-02-06 11:04:24.154259
# 1    2017-10-02 00:00:00.000000    2017-09-13 20:17:41.296915
# 2    2017-03-07 00:00:00.000000    2017-02-06 15:43:04.758566
# 3    2018-04-03 00:00:00.000000    2018-04-03 20:36:43.778451
# 4    2017-05-24 00:00:00.000000    2017-05-04 18:47:45.721758
#
#              ...             product_name_lenght product_description_lenght  \
# 0            ...                              51                        625
# 1            ...                              44                       1428
# 2            ...                              55                        637
# 3            ...                              55                        617
# 4            ...                              49                        558
#
#   product_photos_qty                        product_id  \
# 0                  1  6cdd53843498f92890544667809f1595
# 1                  2  ae5cad88462eb7b7b61401e31c45618e
# 2                  1  0c9ff9d8ed9b9bdd825487b3a66e05f5
# 3                  1  ad0a798e7941f3a5a2fb8139cb62ad78
# 4                  2  eaf2046d4c87809247a30050ea13df03
#
#                           review_id  review_score  review_comment_title  \
# 0  b95df3cef5297e79ef709ba256518f6f             5                   NaN
# 1  59af46052a799e80e2f0c665c587731d             5                   NaN
# 2  a3e6136894621db402a772c6bc72a12a             5                   NaN
# 3  b675ea5a618922f6e679e30531b8957b             4                   NaN
# 4  195a8be6794c487fe6cfbb97b7c61902             5                   NaN
#
#                               review_comment_message  \
# 0                                                NaN
# 1  entrega em 2 dias produto c boa qualidade otim...
# 2  produto veio antes do prazo informado muito ob...
# 3                                                NaN
# 4                                                NaN
#
#          review_creation_date    review_answer_timestamp
# 0  2017-02-07 00:00:00.000000  2017-02-09 02:37:37+00:00
# 1  2017-09-14 00:00:00.000000  2017-09-15 03:43:47+00:00
# 2  2017-02-07 00:00:00.000000  2017-02-10 14:18:53+00:00
# 3  2018-04-04 00:00:00.000000  2018-04-05 02:52:31+00:00
# 4  2017-05-05 00:00:00.000000  2017-05-08 15:20:18+00:00
#
# [5 rows x 25 columns]

# %% [markdown]
# # Padronizando o DataFrame
#
# Retiramos todas as linhas que não possuem reviews para analisar somente os textos.

# %%
e_work_set = e_set[['order_products_value','review_score', 'review_comment_message']].copy()
e_work_set = e_work_set.dropna().reset_index(drop = True)
e_work_set.head()
# Out:
#    order_products_value  review_score  \
# 0                  15.0             5
# 1                 238.9             5
# 2                 160.0             4
# 3                  25.0             3
# 4                 187.0             5
#
#                               review_comment_message
# 0  entrega em 2 dias produto c boa qualidade otim...
# 1  produto veio antes do prazo informado muito ob...
# 2           chegou bem antes do prazo ótimo vendedor
# 3                                  gostei do produto
# 4  o produto veio certinho muito bem embalado e b...

# %% [markdown]
# ## Pre-processamento

# %% [markdown]
# ## Remoção de acentuação

# %%
def remover_acentos(txt):
    return normalize('NFKD', txt).encode('ASCII', 'ignore').decode('ASCII')
# Out:
# amanha e um novo dia cedilha

# %% [markdown]
# ## Remoção de pontuação
#
# Será feita a remoção de acentuação usando uma expressão regular simples.

# %%
pattern = re.compile('[^a-zA-Z\d\s]')
#print(re.sub(pattern,'','Amanhã, iremos a casa!'))

# %% [markdown]
# ## Remoção de Stopwords
#
# As stopwords, palavras que não possuem sentido significativo para a sentença são retiradas através da corpora disponibilizada pela bibliteca NLTK.

# %%
stop_words = set(corpus.stopwords.words('portuguese'))

stop_words_norm = []
for i in stop_words:
    word = remover_acentos(i)
    stop_words_norm.append(word)
    
stop_words_norm.remove('nao')
# Out:
# ['que', 'foramos', 'voce', 'houvesse', 'temos', 'tivera', 'seriam', 'qual', 'depois', 'terei', 'fossem', 'fui', 'tivessem', 'pela', 'estive', 'eram', 'fomos', 'num', 'esteja', 'nas', 'somos', 'elas', 'houver', 'ele', 'houvessemos', 'foram', 'com', 'estejam', 'tive', 'era', 'mas', 'houvera', 'tenhamos', 'eramos', 'teve', 'me', 'seria', 'hei', 'sem', 'minhas', 'tinha', 'nem', 'tera', 'aquelas', 'so', 'numa', 'tu', 'tem', 'sou', 'aquela', 'meus', 'terao', 'foi', 'eles', 'houverei', 'isto', 'delas', 'hajamos', 'serei', 'seriamos', 'a', 'quando', 'seremos', 'aquele', 'sejam', 'tenha', 'formos', 'tivermos', 'ao', 'nossa', 'nossas', 'tinham', 'for', 'estiverem', 'uma', 'houverao', 'nos', 'estivessem', 'tambem', 'fosse', 'aos', 'para', 'pelos', 'estiveram', 'houvermos', 'haja', 'dela', 'essa', 'do', 'ela', 'esse', 'forem', 'como', 'nos', 'estou', 'sera', 'estiveramos', 'tenho', 'mesmo', 'houvemos', 'as', 'estivera', 'o', 'um', 'suas', 'houvessem', 'esteve', 'teremos', 'teria', 'muito', 'esta', 'este', 'mais', 'dos', 'lhes', 'esta', 'aqueles', 'deles', 'essas', 'tinhamos', 'estao', 'sao', 'e', 'da', 'estivessemos', 'por', 'tem', 'estivesse', 'havemos', 'meu', 'tivessemos', 'teus', 'ja', 'tiverem', 'pelas', 'houve', 'ou', 'as', 'tua', 'houveriamos', 'sua', 'tiver', 'nosso', 'a', 'das', 'fossemos', 'de', 'ate', 'estavamos', 'na', 'esses', 'no', 'aquilo', 'estiver', 'tiveram', 'teriam', 'houveramos', 'hajam', 'tivemos', 'em', 'tuas', 'serao', 'entre', 'pelo', 'tiveramos', 'voces', 'seus', 'fora', 'eu', 'estejamos', 'houveria', 'lhe', 'houveram', 'se', 'houveriam', 'estivermos', 'sejamos', 'os', 'estas', 'minha', 'quem', 'estivemos', 'hao', 'houveremos', 'tivesse', 'seu', 'dele', 'seja', 'estes', 'estavam', 'nossos', 'houverem', 'tenham', 'estamos', 'isso', 'te', 'teriamos', 'teu', 'houvera', 'ha', 'estava', 'vos']

# %% [markdown]
# ## Lematização

# %% [markdown]
# A lematização é a redução da palavra a sua forma mais básica, ou seja, substanttivos na forma masculina e no singular, verbos no infinitivo.
#
# O procedimento foi feito adptando o lemmatizador stanford, feito em Java, usando a biblioteca Py4J que cria uma interface com Java para Python

# %% [markdown]
# ## Realização do pré processamento
#
# Ao final do pré-processamento obteremos um texto simplificado, mas que padroniza a estrutura dos comentários e facilita na nossa análise.

# %%
gg = JavaGateway.launch_gateway(classpath="./java/lemmatizerpt.jar;./java/py4j0.10.8.1.jar;./java/stanford-postagger.jar;./java/lemport-0.9.7.jar")
lemmatizer = gg.jvm.lemmatizer.LemmatizerInterface()    

for index,row in e_work_set.iterrows():
    
    # Retiramos a pontuação usando Regex.
    lista_tks = []
    for tk in e_work_set['review_comment_message'][index].split():
        lista_tks.append(re.sub(pattern,'',tk))
    tk_reviews = lista_tks
    
    # Reduz a palavra ao seu lema.
    
    lemmatizer.processLemmas(' '.join(tk_reviews))
    
    list_lemmas = [i for i in lemmatizer.getLemmas()]
    list_tags = [j for j in lemmatizer.getPosTags()]    

    # Removemos os acentos inicialmente.
    tk_reviews = remover_acentos(' '.join(list_lemmas))
       
    # Retira Stopwords.
    tk_reviews = [w for w in tk_reviews.split() if not w in stop_words_norm]
    
    e_work_set.loc[index,'review_tratada'] = ' '.join(tk_reviews)
    e_work_set.loc[index,'pos_tags'] = ' '.join(list_tags)

# %%
e_work_set.to_csv('review_lematizada.csv',encoding = 'utf-8',index = False)

# %%
e_work_set.head()
# Out:
#    order_products_value  review_score  \
# 0                  15.0             5
# 1                 238.9             5
# 2                 160.0             4
# 3                  25.0             3
# 4                 187.0             5
#
#                               review_comment_message  \
# 0  entrega em 2 dias produto c boa qualidade otim...
# 1  produto veio antes do prazo informado muito ob...
# 2           chegou bem antes do prazo ótimo vendedor
# 3                                  gostei do produto
# 4  o produto veio certinho muito bem embalado e b...
#
#                                       review_tratada  \
# 0  entrega 2 dia produto c bom qualidade otimo cu...
# 1  produto vir antes prazo informar obrigar agili...
# 2               chegar bem antes prazo timo vendedor
# 3                                     gostar produto
# 4  produto vir certo bem embalar bem antes prazo ...
#
#                                             pos_tags
# 0                    n prp num n n adv adj n adj n n
# 1            n v-fin prp adj n v-pcp adv v-pcp n adv
# 2                          v-fin adv adv adj n adj n
# 3                                        v-fin adj n
# 4  art n v-fin adj adv adv v-pcp conj-c adv adv a...

# %% [markdown]
# # Extraindo Features das reviews tokenizadas
#
# Agora vamos extrair algumas características das reviews para analisarmos separadamente os textos de reviews para cada pontuação.

# %%
e_set_rev_1 = e_work_set[e_work_set['review_score'] == 1].reset_index(drop = True)
e_set_rev_2 = e_work_set[e_work_set['review_score'] == 2].reset_index(drop = True)
e_set_rev_3 = e_work_set[e_work_set['review_score'] == 3].reset_index(drop = True)
e_set_rev_4 = e_work_set[e_work_set['review_score'] == 4].reset_index(drop = True)
e_set_rev_5 = e_work_set[e_work_set['review_score'] == 5].reset_index(drop = True)
e_set_rev_1.head()
# Out:
#    order_products_value  review_score  \
# 0                134.90             1
# 1                329.99             1
# 2                251.90             1
# 3                979.00             1
# 4                 62.70             1
#
#                               review_comment_message  \
# 0       o correio ainda não fez a entrega to furioso
# 1  não recebi o meu produto e nem fui avisada da ...
# 2  comprei um produto e recebi outro e inferior g...
# 3  não comprem só vai dar dor de cabeça o produto...
# 4  comprei 2 produtos iguais porém em cores difer...
#
#                                       review_tratada  \
# 0             correio ainda fazer entrega to furioso
# 1  receber produto ser avisar faltar item loja en...
# 2  comprar produto receber outro inferior gostar ...
# 3    comprar s ir dar dor cabea produto nunca chegar
# 4  comprar 2 produto igual porm cor diferente che...
#
#                                             pos_tags
# 0            art n adv pron-pers v-fin art n adj adj
# 1  pron-pers v-fin art pron-det n conj-c adv v-fi...
# 2  v-fin art n conj-c v-fin pron-det conj-c adj v...
# 3  pron-pers v-fin pron-pers v-fin v-inf n prp n ...
# 4  v-fin num n adj n prp n adj v-fin prp pron-det...

# %% [markdown]
# ## Análise Exploratória
#
# Será mostrado, como exemplo, o código para extração de cada feature nas reviews de nota 1. Em seguida mostraremos apenas os resultados obtidos para as reviews agrupadas por nota.

# %% [markdown]
# ## Media de Tokens
#
# Com o propósito de analisar o tamanho do texto escrito pelos consumidores ao avaliar um produto, foi feita uma média dos tokens para cada nota.

# %%
def media_tokens(df):
    vectorizer = CountVectorizer(encoding = 'utf_8')
    reviews = []

    for row in df.itertuples():
        reviews.append(row[3])

    tokenized_reviews_all = vectorizer.fit_transform(reviews)
    nr_medio_de_tokens_1 = tokenized_reviews_all.toarray().sum()/len(e_set_rev_1)
    print(("%.2f" % nr_medio_de_tokens_1))

# %% [markdown]
# ## Análise de Sentimento
#
# A análise de sentimento proposta é feita de maneira bem simples. Baseado em uma lista de termos positivos e uma lista de termos negativos calculamos a porcentagem de palavras positivas e negativas no total. Palavras que não estão classificadas em positivas e negativas serão consideradas neutras.
#
# As listas são provenientes do site Kaggle.
# https://www.kaggle.com/rtatman/sentiment-lexicons-for-81-languages

# %% [markdown]
# ### Importando léxico de palavras negativas

# %%
palavras_negativas = []

with open('./sentiment-lexicons/negative_words_pt.txt','r',encoding = 'utf_8') as f:
    for line in f.readlines():
        palavras_negativas.append(line)


lista_negativas = []
for i in palavras_negativas:
    palavra = i.replace('\n', '')
    lista_negativas.append(remover_acentos(palavra))   

lista_negativas = set(lista_negativas)

# %% [markdown]
# ### Importando léxico de palavras positivas

# %%
palavras_positivas = []

with open('./sentiment-lexicons/positive_words_pt.txt','r',encoding = 'utf_8') as f:
    for line in f.readlines():
        palavras_positivas.append(line)


lista_positivas = []
for i in palavras_positivas:
    palavra = i.replace('\n', '')
    lista_positivas.append(remover_acentos(palavra))   

lista_positivas = set(lista_positivas)

# %% [markdown]
# ### Definindo função para contagem de tokens positivos e negativos

# %%
# Recebe uma string e comparar as palavras que estão no léxico positivo e negativo

def sent_count(text):
    pos_count = 0
    neg_count = 0
    for token in text.split():
        if token in lista_positivas:
            pos_count += 1
        if token in lista_negativas:
            neg_count += 1
        return((pos_count,neg_count))

# %%
for index,row in e_work_set.iterrows():
    x = e_work_set['review_tratada'][index]

    if x == '':
        continue
    sentimentos = sent_count(x)
    e_work_set.loc[index,'nr_tk_positivos'] = sentimentos[0]
    e_work_set.loc[index,'porcent_tk_positivos'] = sentimentos[0]/len(x.split())
    e_work_set.loc[index,'nr_tk_negativos'] = sentimentos[1]
    e_work_set.loc[index,'porcent_tk_negativos'] = sentimentos[1]/len(x.split())
    
    if e_work_set['porcent_tk_positivos'][index] == e_work_set['porcent_tk_negativos'][index]:
        e_work_set.loc[index,'sentimento'] = 'Neutro'
        
    elif e_work_set['porcent_tk_positivos'][index] > e_work_set['porcent_tk_negativos'][index]:
        e_work_set.loc[index,'sentimento'] = 'Positivo'
        
    else:
        e_work_set.loc[index,'sentimento'] = 'Negativo'

# %% [markdown]
# Após a contagem de termos positivos e negativos as reviews foram classificadas em sentimento negativo e positivo beasedo apenas na porcentagem de termos positivos e termos negativos.

# %% [markdown]
# ## Separando os dataframes por review

# %%
e_set_rev_1 = e_work_set[e_work_set['review_score'] == 1].reset_index(drop = True)
e_set_rev_2 = e_work_set[e_work_set['review_score'] == 2].reset_index(drop = True)
e_set_rev_3 = e_work_set[e_work_set['review_score'] == 3].reset_index(drop = True)
e_set_rev_4 = e_work_set[e_work_set['review_score'] == 4].reset_index(drop = True)
e_set_rev_5 = e_work_set[e_work_set['review_score'] == 5].reset_index(drop = True)
e_set_rev_1.head()
# Out:
#    order_products_value  review_score  \
# 0                134.90             1
# 1                329.99             1
# 2                251.90             1
# 3                979.00             1
# 4                 62.70             1
#
#                               review_comment_message  \
# 0       o correio ainda não fez a entrega to furioso
# 1  não recebi o meu produto e nem fui avisada da ...
# 2  comprei um produto e recebi outro e inferior g...
# 3  não comprem só vai dar dor de cabeça o produto...
# 4  comprei 2 produtos iguais porém em cores difer...
#
#                                       review_tratada  \
# 0             correio ainda fazer entrega to furioso
# 1  receber produto ser avisar faltar item loja en...
# 2  comprar produto receber outro inferior gostar ...
# 3    comprar s ir dar dor cabea produto nunca chegar
# 4  comprar 2 produto igual porm cor diferente che...
#
#                                             pos_tags  nr_tk_positivos  \
# 0            art n adv pron-pers v-fin art n adj adj              0.0
# 1  pron-pers v-fin art pron-det n conj-c adv v-fi...              0.0
# 2  v-fin art n conj-c v-fin pron-det conj-c adj v...              0.0
# 3  pron-pers v-fin pron-pers v-fin v-inf n prp n ...              0.0
# 4  v-fin num n adj n prp n adj v-fin prp pron-det...              0.0
#
#    porcent_tk_positivos  nr_tk_negativos  porcent_tk_negativos sentimento
# 0                   0.0              0.0                   0.0     Neutro
# 1                   0.0              0.0                   0.0     Neutro
# 2                   0.0              0.0                   0.0     Neutro
# 3                   0.0              0.0                   0.0     Neutro
# 4                   0.0              0.0                   0.0     Neutro

# %%
e_set_rev_5['sentimento'].value_counts()

df = pd.DataFrame()
df['sent_1'] = e_set_rev_1['sentimento'].value_counts()
df['sent_2'] = e_set_rev_2['sentimento'].value_counts()
df['sent_3'] = e_set_rev_3['sentimento'].value_counts()
df['sent_4'] = e_set_rev_4['sentimento'].value_counts()
df['sent_5'] = e_set_rev_5['sentimento'].value_counts()

df.head()
# Out:
#           sent_1  sent_2  sent_3  sent_4  sent_5
# Neutro      7722    1867    3005    4127   13392
# Negativo     844     220     307     291     575
# Positivo     734     266     654    1683    6788

# %%
eval_df_1 = e_set_rev_1[e_set_rev_1['sentimento'] == 'Positivo']
#eval_df_1.head(len(eval_df_1))
# Out:
#       order_products_value  review_score  \
# 12                  113.00             1
# 16                   40.00             1
# 19                  238.00             1
# 37                   46.90             1
# 42                   19.90             1
# 59                  175.00             1
# 63                  149.97             1
# 67                   69.90             1
# 68                   69.90             1
# 74                  199.99             1
# 88                   74.90             1
# 118                  99.99             1
# 120                 139.98             1
# 126                 881.64             1
# 139                 169.90             1
# 172                  69.33             1
# 173                 628.00             1
# 187                  88.90             1
# 190                 505.50             1
# 196                  89.90             1
# 204                  52.00             1
# 208                  49.00             1
# 210                  25.99             1
# 225                 129.99             1
# 243                  52.64             1
# 250                  89.90             1
# 337                  25.90             1
# 341                  34.99             1
# 347                 103.90             1
# 350                 149.85             1
# ...                    ...           ...
# 8979                 33.90             1
# 9052                385.98             1
# 9057                 65.98             1
# 9061                269.00             1
# 9062                 86.90             1
# 9070               1161.00             1
# 9074                 99.99             1
# 9085                 69.90             1
# 9086                 67.90             1
# 9095                179.00             1
# 9106                 88.89             1
# 9112                229.99             1
# 9133                 53.90             1
# 9143                160.00             1
# 9152                599.98             1
# 9162                 98.99             1
# 9168                 84.99             1
# 9169                107.80             1
# 9176                224.50             1
# 9179                 48.90             1
# 9187                689.99             1
# 9207                 79.90             1
# 9212                 19.90             1
# 9235                 34.50             1
# 9236                 55.00             1
# 9247                 69.00             1
# 9257                 49.90             1
# 9263                299.74             1
# 9279                 35.00             1
# 9281                 50.00             1
#
#                                  review_comment_message  \
# 12    não foi entregue o produto que comprei enviara...
# 16    bom dia o lustre anunciado era azul claro foi ...
# 19    foi entregue produto diferente do que comprei ...
# 37    não recomendo essa loja pra ninguém comprei o ...
# 42    não gostei do produto não funciona como aparec...
# 59    valor do produto no site 175 00 mais frete de ...
# 63    não recomendo demorou muito para a entrega e s...
# 67    gostaria de lembrar que esse pedido eu tinha c...
# 68    bom dia ainda não recebi meu produto ainda sen...
# 74    foram compradas duas cadeiras uma azul e outra...
# 88    foram compradas 2 cortinas de 6m e 3m e foi en...
# 118   foi anunciado um produto e veio outro totalmen...
# 120   não recomendo além da demora para entregar che...
# 126   boa tarde os produtos foram entregues ontem em...
# 139   não recomendo essa loja pois depois de tanta d...
# 172   não foi entregue a chupeta veio apenas o ester...
# 173   boa noite fiz uma compra online pela baratheon...
# 187   recomendaria pelas compras que já fiz antes er...
# 190   não sei o que houve era pra ser entregue o pro...
# 196   não recomendo esta loja nem a loja stark com p...
# 204                boa tarde ainda não recebi o produto
# 208   não gostei do relógio complicado na marcação d...
# 210   não recomendo essa loja pra ninguém comprar po...
# 225   gostaria de saber o que houve com o meu pedido...
# 243   foi entregue até o momento a manta ainda não r...
# 250    não gostei muito ruim não compro mais nessa loja
# 337             bom dia não gostei de péssima qualidade
# 341                             favor entrar em contato
# 347            foi entregue parcial faltam os 3 lustres
# 350   foi encaminhado ontem um e mail informando que...
# ...                                                 ...
# 8979  boa tarde comprei tres produtos so chegou dois...
# 9052  foi entregue apenas uma cadeira e nao duas con...
# 9057  prometem entregar no prazo e demoram mais além...
# 9061  foi enviado um produto usado mesmo sem entende...
# 9062         sei que os correios também estar a desejar
# 9070                                               zero
# 9074  boa tarde recebi somente um jogo de toalha pon...
# 9085  foi roubada ja mandei e mail mas até agora nad...
# 9086  bom dia quero saber quando vou receber o meu p...
# 9095  boa noite não recebi o produto correios nunca ...
# 9106                                   não foi entregue
# 9112                            superou as expectativas
# 9133             so foi entregue o sexto os quadros não
# 9143  por favor eu já registrei há 48 horas atrás qu...
# 9152  não gostei comprei 2 produtos no mesmo pedido ...
# 9162  realizei a compra de 2 colchas de solteiro e s...
# 9168  não gostei do produto quero trocar em outro pr...
# 9169  foi feito pedido de dois pendente e faturado o...
# 9176  bom dia ja fiz duas reclamações e ainda nao fu...
# 9179  bom dia ja fiz duas reclamações e ainda nao fu...
# 9187  não dei 5 estrelas pois faltou manual em portu...
# 9207  bom dia as toalhas são de ma qualidade super f...
# 9212  sou antigo com fidelidade nunca tinha ocorrido...
# 9235                                                bom
# 9236                                 por favor reenviar
# 9247                               não é bom o material
# 9257  não gostei pois parece mais um manguito com a ...
# 9263  bom dia compra a mais de 30 dias e não recebi ...
# 9279                   não recomendo comprar nesse site
# 9281  seria muito bom mas como eu recebi o produto c...
#
#                                          review_tratada  \
# 12    ser entregar produto comprar enviar outro prod...
# 16    bom dia lustre anunciar ser azul claro ser ent...
# 19    ser entregar produto diferente comprar estar e...
# 37    recomendar loja pra ningum comprar presente fi...
# 42         gostar produto funcionar aparecer propaganda
# 59    valor produto site 175 00 frete 12 73 emitir n...
# 63    recomendar demorar entrega contar produto pssi...
# 67    gostar lembrar pedido ter cancelar ato compra ...
# 68    bom dia ainda receber produto ainda ser assim ...
# 74    ser comprar dois cadeira azul outro verde ser ...
# 88    ser comprar 2 cortina 6m 3m ser entregar apena...
# 118   ser anunciar produto vir outro totalmente infe...
# 120   recomendar alm demora entregar chegar apenas c...
# 126   bom tarde produto ser entregar ontem pleno dom...
# 139   recomendar loja pois tanto demora m enviar ape...
# 172   ser entregar chupeta vir apenas esterilizador ...
# 173   bom noite fazer compra onlinar baratheon pedir...
# 187   recomendar compra j fazer antes ser rpidar ent...
# 190   saber haver ser pra ser entregar produto at di...
# 196            recomendar loja loja stark pois parceiro
# 204                     bom tarde ainda receber produto
# 208   gostar relgio complicar marcar horrio caixa re...
# 210   recomendar loja pra ningum comprar porque fica...
# 225   gostar saber haver pedido j t m comprar produt...
# 243   ser entregar at momento manta ainda receber ta...
# 250                      gostar ruim comprar nessa loja
# 337                     bom dia gostar pssima qualidade
# 341                                favor entrar contato
# 347                 ser entregar parcial faltar 3 lustr
# 350   ser encaminhar ontem mail informar mercadoria ...
# ...                                                 ...
# 8979  bom tarde comprar tr produto chegar dois nao t...
# 9052  ser entregar apenas cadeira naar dois conforme...
# 9057  prometer entregar prazo demorar alm disso faze...
# 9061  ser enviar produto usar entender informatica n...
# 9062                  saber correio tambm estar desejar
# 9070                                               zero
# 9074  bom tarde receber somente jogo toalha ponto ru...
# 9085  ser roubar mandei mail at agora nada ningum re...
# 9086  bom dia querer saber ir receber pedido j passa...
# 9095  bom noite receber produto correio nunca atuali...
# 9106                                       ser entregar
# 9112                                superar expectativa
# 9133                          ser entregar sexto quadro
# 9143  favor j registrar h 48 hora atr receber capa c...
# 9152  gostar comprar 2 produto pedir s receber 1 pra...
# 9162  realizar compra 2 colcha solteiro s receber 1 ...
# 9168  gostar produto querer trocar outro produto cab...
# 9169  ser fazer pedir dois pendente faturar dois car...
# 9176  bom dia fazer dois reclamae ainda naar ser res...
# 9179  bom dia fazer dois reclamae ainda naar ser res...
# 9187  dar 5 estrela pois faltar manual portugu tesou...
# 9207  bom dia toalha ma qualidade super fino parecer...
# 9212  ser antigo fidelidade nunca ter ocorrer dever ...
# 9235                                                bom
# 9236                                     favor reenviar
# 9247                                       bom material
# 9257  gostar pois parecer manguito ponta costurado m...
# 9263  bom dia compra 30 dia receber produto solicita...
# 9279                      recomendar comprar nesse site
# 9281  ser bom receber produto defeito gostar ser bem...
#
#                                                pos_tags  nr_tk_positivos  \
# 12    pron-pers v-fin v-pcp art n pron-indp v-fin v-...              1.0
# 16    adj n art n v-pcp v-fin adj adv v-fin v-pcp ad...              1.0
# 19    v-fin v-pcp n adj adj pron-indp v-fin conj-c v...              1.0
# 37    pron-pers v-fin pron-det n prp n v-fin art n a...              1.0
# 42    pron-pers v-fin adj n pron-pers v-fin adv v-fi...              1.0
# 59    n adj n pron-pers n num num adv n prp num num ...              1.0
# 63    pron-pers v-fin v-fin adv prp art n conj-c prp...              1.0
# 67    v-fin prp v-inf conj-s pron-det n pron-pers v-...              1.0
# 68    adj n adv pron-pers v-fin pron-det n adv v-ger...              1.0
# 74    v-fin v-pcp num n art adj conj-c pron-det adj ...              1.0
# 88    v-fin v-pcp num adj prp num conj-c num conj-c ...              1.0
# 118   v-fin v-pcp art n conj-c v-fin pron-det adv ad...              1.0
# 120   pron-pers v-fin v-fin pron-pers n prp v-inf v-...              1.0
# 126   adj n art n v-fin v-pcp adv prp adj n pron-per...              1.0
# 139   pron-pers v-fin pron-det n adv adv prp pron-de...              1.0
# 172   pron-pers v-fin v-pcp art n v-fin adv art n pr...              1.0
# 173   adj n v-fin art n v-fin n adv v-pcp num num n ...              1.0
# 187   v-fin adj n pron-indp pron-pers v-fin adv v-fi...              1.0
# 190   pron-pers v-fin pron-det pron-indp v-fin v-fin...              1.0
# 196   pron-pers v-fin pron-det n adv art n n prp con...              1.0
# 204                   adj adv adv pron-pers v-fin art n              1.0
# 208   pron-pers v-fin adj n v-pcp pron-pers v-fin ad...              1.0
# 210   pron-pers v-fin pron-det n prp adv v-inf conj-...              1.0
# 225   v-fin prp v-inf pron-det pron-indp v-fin prp a...              1.0
# 243   v-fin v-pcp n art n art n adv pron-pers v-fin ...              1.0
# 250   pron-pers v-fin adv adj pron-pers v-fin adv adj n              1.0
# 337                     adj n pron-pers v-fin prp adj n              1.0
# 341                                       n v-inf prp n              1.0
# 347                   v-fin v-pcp adj v-fin art num adj              1.0
# 350   v-fin v-pcp adv num conj-c n v-ger conj-s art ...              1.0
# ...                                                 ...              ...
# 8979  adj n v-fin n n adj v-fin num prp pron-indp n ...              1.0
# 9052  v-fin v-pcp adv art n conj-c v-fin num adv adv...              1.0
# 9057  v-fin v-inf pron-pers n conj-c v-fin adv n adv...              1.0
# 9061  v-fin v-pcp art n v-pcp adv prp v-inf adv prp ...              1.0
# 9062               v-fin conj-s art n n v-inf prp v-inf              1.0
# 9070                                                num              1.0
# 9074  adj n v-fin adv art n prp n n adj prop v-ger a...              1.0
# 9085  v-fin v-pcp adj n conj-c n conj-c n adv n adj ...              1.0
# 9086  adj n v-fin v-inf adv v-fin v-inf art pron-det...              1.0
# 9095  adj n pron-pers v-fin art n n adv v-fin art n ...              1.0
# 9106                              pron-pers v-fin v-pcp              1.0
# 9112                                        v-fin art n              1.0
# 9133              n v-fin v-pcp art adj art n pron-pers              1.0
# 9143  prp n pron-pers n v-fin prop num n n pron-indp...              1.0
# 9152  pron-pers v-fin v-fin num n pron-pers adv v-pc...              1.0
# 9162  v-fin art n prp num n prp adj conj-c n v-fin n...              1.0
# 9168  pron-pers v-fin adj n v-fin v-inf prp pron-det...              1.0
# 9169  v-fin v-pcp v-pcp prp num adj conj-c v-pcp art...              1.0
# 9176  adj n adj v-fin num n conj-c adv v-fin v-fin v...              1.0
# 9179  adj n adj v-fin num n conj-c adv v-fin v-fin v...              1.0
# 9187  pron-pers v-fin num n conj-s v-fin n prp n adj...              1.0
# 9207  adj n art n adj prp adj n adj adj v-fin v-fin ...              1.0
# 9212  v-fin adj prp n adv v-fin v-pcp prp v-fin v-in...              1.0
# 9235                                                adj              1.0
# 9236                                          prp n adj              1.0
# 9247                                pron-pers adj art n              1.0
# 9257  pron-pers v-fin conj-s v-fin adv num n prp art...              1.0
# 9263  adj n n art adv prp num n conj-c pron-pers v-f...              1.0
# 9279                          pron-pers v-fin v-inf n n              1.0
# 9281  v-fin adv adj conj-c adv pron-pers v-fin art n...              1.0
#
#       porcent_tk_positivos  nr_tk_negativos  porcent_tk_negativos sentimento
# 12                0.050000              0.0                   0.0   Positivo
# 16                0.090909              0.0                   0.0   Positivo
# 19                0.100000              0.0                   0.0   Positivo
# 37                0.040000              0.0                   0.0   Positivo
# 42                0.200000              0.0                   0.0   Positivo
# 59                0.058824              0.0                   0.0   Positivo
# 63                0.055556              0.0                   0.0   Positivo
# 67                0.050000              0.0                   0.0   Positivo
# 68                0.100000              0.0                   0.0   Positivo
# 74                0.083333              0.0                   0.0   Positivo
# 88                0.066667              0.0                   0.0   Positivo
# 118               0.066667              0.0                   0.0   Positivo
# 120               0.050000              0.0                   0.0   Positivo
# 126               0.055556              0.0                   0.0   Positivo
# 139               0.055556              0.0                   0.0   Positivo
# 172               0.100000              0.0                   0.0   Positivo
# 173               0.045455              0.0                   0.0   Positivo
# 187               0.076923              0.0                   0.0   Positivo
# 190               0.058824              0.0                   0.0   Positivo
# 196               0.166667              0.0                   0.0   Positivo
# 204               0.200000              0.0                   0.0   Positivo
# 208               0.050000              0.0                   0.0   Positivo
# 210               0.100000              0.0                   0.0   Positivo
# 225               0.090909              0.0                   0.0   Positivo
# 243               0.125000              0.0                   0.0   Positivo
# 250               0.200000              0.0                   0.0   Positivo
# 337               0.200000              0.0                   0.0   Positivo
# 341               0.333333              0.0                   0.0   Positivo
# 347               0.166667              0.0                   0.0   Positivo
# 350               0.066667              0.0                   0.0   Positivo
# ...                    ...              ...                   ...        ...
# 8979              0.071429              0.0                   0.0   Positivo
# 9052              0.125000              0.0                   0.0   Positivo
# 9057              0.045455              0.0                   0.0   Positivo
# 9061              0.111111              0.0                   0.0   Positivo
# 9062              0.200000              0.0                   0.0   Positivo
# 9070              1.000000              0.0                   0.0   Positivo
# 9074              0.041667              0.0                   0.0   Positivo
# 9085              0.111111              0.0                   0.0   Positivo
# 9086              0.038462              0.0                   0.0   Positivo
# 9095              0.076923              0.0                   0.0   Positivo
# 9106              0.500000              0.0                   0.0   Positivo
# 9112              0.500000              0.0                   0.0   Positivo
# 9133              0.250000              0.0                   0.0   Positivo
# 9143              0.037037              0.0                   0.0   Positivo
# 9152              0.040000              0.0                   0.0   Positivo
# 9162              0.071429              0.0                   0.0   Positivo
# 9168              0.083333              0.0                   0.0   Positivo
# 9169              0.047619              0.0                   0.0   Positivo
# 9176              0.032258              0.0                   0.0   Positivo
# 9179              0.032258              0.0                   0.0   Positivo
# 9187              0.050000              0.0                   0.0   Positivo
# 9207              0.090909              0.0                   0.0   Positivo
# 9212              0.083333              0.0                   0.0   Positivo
# 9235              1.000000              0.0                   0.0   Positivo
# 9236              0.500000              0.0                   0.0   Positivo
# 9247              0.500000              0.0                   0.0   Positivo
# 9257              0.058824              0.0                   0.0   Positivo
# 9263              0.090909              0.0                   0.0   Positivo
# 9279              0.250000              0.0                   0.0   Positivo
# 9281              0.090909              0.0                   0.0   Positivo
#
# [734 rows x 10 columns]

# %%
eval_df_5 = e_set_rev_5[e_set_rev_5['sentimento'] == 'Negativo']
eval_df_5.head(len(eval_df_5))
# Out:
#        order_products_value  review_score  \
# 0                     15.00             5
# 12                    23.99             5
# 183                   34.30             5
# 196                   68.90             5
# 282                   19.90             5
# 334                  330.00             5
# 380                   29.99             5
# 427                   79.90             5
# 456                  699.00             5
# 461                   89.99             5
# 530                  167.99             5
# 549                   79.90             5
# 554                  159.90             5
# 575                   21.88             5
# 636                  139.99             5
# 723                  149.00             5
# 743                  135.00             5
# 767                  550.00             5
# 779                  204.00             5
# 896                   94.30             5
# 914                   79.90             5
# 1026                  69.99             5
# 1162                  83.90             5
# 1184                  45.90             5
# 1244                  39.99             5
# 1253                  69.90             5
# 1267                 294.99             5
# 1303                  72.98             5
# 1331                 109.90             5
# 1332                 162.90             5
# ...                     ...           ...
# 19873                249.90             5
# 19879                269.00             5
# 19884                118.70             5
# 19885                 31.90             5
# 19928                 21.33             5
# 19980                 28.99             5
# 19983                 93.00             5
# 20016                109.90             5
# 20030                 70.90             5
# 20036                599.97             5
# 20085                109.90             5
# 20126                229.00             5
# 20137                135.00             5
# 20147                 18.99             5
# 20169                199.99             5
# 20226                 45.90             5
# 20245                286.40             5
# 20258                299.99             5
# 20306                 29.90             5
# 20433                 37.99             5
# 20549                 79.00             5
# 20602                 48.00             5
# 20604                439.90             5
# 20623                 39.90             5
# 20673                259.90             5
# 20690                 39.90             5
# 20710                170.00             5
# 20711                307.30             5
# 20723                 19.90             5
# 20734                 64.90             5
#
#                                   review_comment_message  \
# 0      entrega em 2 dias produto c boa qualidade otim...
# 12                                estou muito satisfeito
# 183                  objeto muito bonito veio tudo certo
# 196    estou bem satisfeita com minba compra vale a pena
# 282                                entrega com segurança
# 334    a entrega chegou antes do esperado em perfeita...
# 380    as correntes são boas e o material também a co...
# 427      odores meus lençóis de cetim super recomendo 10
# 456                                          sem queixas
# 461                                        sem problemas
# 530    estou muito satisfeita com minha compra que ch...
# 549      odores meus lençóis de cetim super recomendo 10
# 554            entrega dentro do prazo e produto correto
# 575      entrega dentro do prazo e produto como descrito
# 636    estou achando muito demorado há entrega ficara...
# 723    entrega realizada no prazo produto de acordo c...
# 743                 entrega dentro do prazo estabelecido
# 767    estou muito satisfeita com a cadeira para salã...
# 779    demorou um pouco pra entregar mas entregou no ...
# 896    entrega com boa antecedência muito bom recomen...
# 914      odores meus lençóis de cetim super recomendo 10
# 1026                  a entrega chegou antes do previsto
# 1162                                  demorou mas chegou
# 1184                             entrega dentro do prazo
# 1244                    estão fazendo excelente trabalho
# 1253   entrega dentro do tempo previsto mercadoria de...
# 1267   a entrega aconteceu muito antes do esperado e ...
# 1303   entrega dentro do prazo produto conforme pedid...
# 1331   demorou um pouco a chegar mas veio dentro do p...
# 1332   parabéns não foi no endereço que mandei tive q...
# ...                                                  ...
# 19873  responsabilidade total e feedback constante pa...
# 19879  estou satisfeita com os pedido pois todos cheg...
# 19884                             envio rápido recomendo
# 19885  a entrega foi ótima rápida e o produto é muito...
# 19928  entrega feita no prazo e o produto e muito bom...
# 19980                    atrasou um pouco devido a greve
# 19983  total sinceridade com o cliente entrega muito ...
# 20016  demorou um pouquinho mas chegou dentro do praz...
# 20030        estou satisfeito com a aquisição do produto
# 20036  faltaram 2 dos 3 produtos comprados aguardando...
# 20085  infelizmente não sabia a diferença e comprei p...
# 20126  mesmo estando dentro do prazo a entrega poderi...
# 20137  estava previsto pra 17 dias e chegou em uma se...
# 20147                    entrega imediata e satisfatória
# 20169  estou muito contente com a rapidez e excelênci...
# 20226                    estou muito feliz com o produto
# 20245  estou muito satisfeita o produto é lindo perfeito
# 20258    envio muito rápido e chegou muito rápido também
# 20306                 envio rápido produto como descrito
# 20433                         pena que o prazo foi longo
# 20549               a entrega rápido e produto muito bom
# 20602  estou super satisfeita com meus produtos o pra...
# 20604                             estou muito satisfeita
# 20623                   entrega com rapidez e excelencia
# 20673          estou super satisfeita com a minha compra
# 20690  estou muito satisfeito com sua competência obr...
# 20710  estava atrás desse produto a muito tempo conse...
# 20711                           não troco por outra loja
# 20723                           alta qualidade recomendo
# 20734                         a entrega foi surpe rapida
#
#                                           review_tratada  \
# 0      entrega 2 dia produto c bom qualidade otimo cu...
# 12                                      estar satisfazer
# 183                         objeto bonito vir tudo certo
# 196         estar bem satisfazer minba compra valer pena
# 282                                     entrega segurana
# 334         entrega chegar antes esperar perfeito condie
# 380    corrente bom material tambm corrente grosso se...
# 427                 odor lenil cetim super recomendar 10
# 456                                               queixa
# 461                                             problema
# 530    estar satisfazer compra chegar at antes prazo dar
# 549                 odor lenil cetim super recomendar 10
# 554                 entrega dentro prazo produto correto
# 575               entrega dentro prazo produto descrever
# 636    estar achar demorar h entregar ficar entregar ...
# 723    entrega realizar prazo produto acordo especificae
# 743                     entrega dentro prazo estabelecer
# 767    estar satisfazer cadeira salo beleza timo prod...
# 779    demorar pouco pra entregar entregar prazo tudo...
# 896          entrega bom antecedncia bom recomendar todo
# 914                 odor lenil cetim super recomendar 10
# 1026                         entrega chegar antes prever
# 1162                                      demorar chegar
# 1184                                entrega dentro prazo
# 1244                      estar fazer excelente trabalho
# 1253   entrega dentro tempo prever mercadoria tima qu...
# 1267   entrega acontecer antes esperar produto vir co...
# 1303   entrega dentro prazo produto conforme pedir re...
# 1331   demorar pouco chegar vir dentro prazo ver q pr...
# 1332   parar ser endereo mandar ter buscar produto m ...
# ...                                                  ...
# 19873  responsabilidade total feedback constante para...
# 19879  estar satisfazer pedido pois todo chegar dentr...
# 19884                             envio rpido recomendar
# 19885                 entrega ser tima rpida produto bom
# 19928            entrega fazer prazo produto bom obrigar
# 19980                         atrasar pouco devido greve
# 19983  total sinceridade cliente entregar rpidar tota...
# 20016  demorar pouquinho chegar dentro prazo gostar p...
# 20030                   estar satisfazer aquisio produto
# 20036  faltar 2 3 produto comprar aguardar soluo empresa
# 20085  infelizmente saber diferena comprar dar presen...
# 20126  estar dentro prazo entrega poder ter ser fazer...
# 20137  estar prever pra 17 dia chegar semana perfeito...
# 20147                       entrega imediato satisfatria
# 20169    estar contente rapidez excelncer entrega pedido
# 20226                                estar feliz produto
# 20245           estar satisfazer produto lindar perfeito
# 20258                      envio rpido chegar rper tambm
# 20306                      envio rpido produto descrever
# 20433                               pena prazo ser longo
# 20549                          entrega rpido produto bom
# 20602  estar super satisfazer produto prazo entrega s...
# 20604                                   estar satisfazer
# 20623                         entrega rapidez excelencia
# 20673                      estar super satisfazer compra
# 20690                estar satisfazer competncia obrigar
# 20710  estar atr dar produto tempo conseguir preo bem...
# 20711                                   troco outro loja
# 20723                          alto qualidade recomendar
# 20734                           entrega ser surpe rapida
#
#                                                 pos_tags  nr_tk_positivos  \
# 0                        n prp num n n adv adj n adj n n              0.0
# 12                                       v-fin adv v-pcp              0.0
# 183                   n adv adj v-fin pron-indp pron-det              0.0
# 196                  v-fin adv v-pcp prp n n v-fin art n              0.0
# 282                                              n prp n              0.0
# 334                  art n v-fin adv adj v-pcp prp adj n              0.0
# 380    art n adj adj conj-c art n n prp n adj v-ger p...              0.0
# 427                   n pron-det adj prp n adj v-fin num              0.0
# 456                                                prp n              0.0
# 461                                                prp n              0.0
# 530    v-fin adv v-pcp prp pron-det n pron-indp v-fin...              0.0
# 549                   n pron-det adj prp n adj v-fin num              0.0
# 554                             n adv adj n conj-c n adj              0.0
# 575                       n adv adj n conj-c n prp v-pcp              0.0
# 636    v-fin v-ger adv v-pcp n v-fin v-fin prp pron-p...              0.0
# 723                n v-pcp pron-pers n n prp n prp art n              0.0
# 743                                    n adv adj n v-pcp              0.0
# 767    v-fin adv v-pcp prp art n prp n prp n adj n v-...              0.0
# 779    v-fin art pron-det prp v-inf conj-c v-fin pron...              0.0
# 896               n prp adj n adv adj v-fin prp pron-det              0.0
# 914                   n pron-det adj prp n adj v-fin num              0.0
# 1026                           art n v-fin adv adj v-pcp              0.0
# 1162                                  v-fin conj-c v-fin              0.0
# 1184                                         n adv adj n              0.0
# 1244                                   v-fin v-ger adj n              0.0
# 1253       n adv adj n v-pcp n prp adj n pron-pers v-fin              0.0
# 1267   art n v-fin adv prp adj v-pcp conj-c art n v-f...              0.0
# 1303                       n adv adj n n adv v-pcp v-fin              0.0
# 1331   v-fin art pron-det prp v-inf conj-c v-fin adv ...              0.0
# 1332   v-fin pron-pers v-fin pron-pers adj pron-indp ...              0.0
# ...                                                  ...              ...
# 19873               n adj conj-c n adj v-fin art n adj n              0.0
# 19879  v-fin v-pcp prp art n conj-s pron-det v-fin ad...              0.0
# 19884                                        n adj v-fin              0.0
# 19885             art n v-fin adj n conj-c art n adv adj              0.0
# 19928  n v-pcp pron-pers n conj-c art n conj-c adv ad...              0.0
# 19980                       v-fin art pron-det adj art n              0.0
# 19983  adj n prp art n v-fin pron-det v-pcp adv v-pcp...              0.0
# 20016  v-fin art n conj-c v-fin adv adj n conj-c pron...              0.0
# 20030                        v-fin v-pcp prp art n adj n              0.0
# 20036              v-fin num n num n v-pcp v-ger adj n n              0.0
# 20085  adv pron-pers v-fin prp n conj-c v-fin prp v-i...              0.0
# 20126  adv v-ger adv adj n art n v-fin v-inf v-pcp v-...              0.0
# 20137  v-fin v-pcp prp num n conj-c v-fin prp art n p...              0.0
# 20147                                     n adj conj-c n              0.0
# 20169  v-fin adv adj prp art n conj-c v-fin pron-pers...              0.0
# 20226                            v-fin adv adj prp art n              0.0
# 20245                    v-fin adv v-pcp art n v-ger adj              0.0
# 20258            n adv adj conj-c v-fin pron-det v-pcp n              0.0
# 20306                                  n adj n adv v-pcp              0.0
# 20433                        n pron-indp art n v-fin adj              0.0
# 20549                         art n adj conj-c n adv adj              0.0
# 20602  v-fin adj v-pcp prp pron-det n art n prp n v-f...              0.0
# 20604                                    v-fin adv v-pcp              0.0
# 20623                                   n prp n conj-c n              0.0
# 20673                 v-fin adj v-pcp prp art pron-det n              0.0
# 20690               v-fin adv v-pcp prp pron-det n v-pcp              0.0
# 20710  v-fin adj v-fin n prp pron-det n v-fin prp art...              0.0
# 20711                         pron-pers n prp pron-det n              0.0
# 20723                                        adj n v-fin              0.0
# 20734                                  art n v-fin adj n              0.0
#
#        porcent_tk_positivos  nr_tk_negativos  porcent_tk_negativos sentimento
# 0                       0.0              1.0              0.100000   Negativo
# 12                      0.0              1.0              0.500000   Negativo
# 183                     0.0              1.0              0.200000   Negativo
# 196                     0.0              1.0              0.142857   Negativo
# 282                     0.0              1.0              0.500000   Negativo
# 334                     0.0              1.0              0.166667   Negativo
# 380                     0.0              1.0              0.111111   Negativo
# 427                     0.0              1.0              0.166667   Negativo
# 456                     0.0              1.0              1.000000   Negativo
# 461                     0.0              1.0              1.000000   Negativo
# 530                     0.0              1.0              0.125000   Negativo
# 549                     0.0              1.0              0.166667   Negativo
# 554                     0.0              1.0              0.200000   Negativo
# 575                     0.0              1.0              0.200000   Negativo
# 636                     0.0              1.0              0.066667   Negativo
# 723                     0.0              1.0              0.166667   Negativo
# 743                     0.0              1.0              0.250000   Negativo
# 767                     0.0              1.0              0.100000   Negativo
# 779                     0.0              1.0              0.125000   Negativo
# 896                     0.0              1.0              0.166667   Negativo
# 914                     0.0              1.0              0.166667   Negativo
# 1026                    0.0              1.0              0.250000   Negativo
# 1162                    0.0              1.0              0.500000   Negativo
# 1184                    0.0              1.0              0.333333   Negativo
# 1244                    0.0              1.0              0.250000   Negativo
# 1253                    0.0              1.0              0.125000   Negativo
# 1267                    0.0              1.0              0.125000   Negativo
# 1303                    0.0              1.0              0.142857   Negativo
# 1331                    0.0              1.0              0.066667   Negativo
# 1332                    0.0              1.0              0.066667   Negativo
# ...                     ...              ...                   ...        ...
# 19873                   0.0              1.0              0.142857   Negativo
# 19879                   0.0              1.0              0.100000   Negativo
# 19884                   0.0              1.0              0.333333   Negativo
# 19885                   0.0              1.0              0.166667   Negativo
# 19928                   0.0              1.0              0.166667   Negativo
# 19980                   0.0              1.0              0.250000   Negativo
# 19983                   0.0              1.0              0.125000   Negativo
# 20016                   0.0              1.0              0.142857   Negativo
# 20030                   0.0              1.0              0.250000   Negativo
# 20036                   0.0              1.0              0.125000   Negativo
# 20085                   0.0              1.0              0.071429   Negativo
# 20126                   0.0              1.0              0.041667   Negativo
# 20137                   0.0              1.0              0.071429   Negativo
# 20147                   0.0              1.0              0.333333   Negativo
# 20169                   0.0              1.0              0.166667   Negativo
# 20226                   0.0              1.0              0.333333   Negativo
# 20245                   0.0              1.0              0.200000   Negativo
# 20258                   0.0              1.0              0.200000   Negativo
# 20306                   0.0              1.0              0.250000   Negativo
# 20433                   0.0              1.0              0.250000   Negativo
# 20549                   0.0              1.0              0.250000   Negativo
# 20602                   0.0              1.0              0.083333   Negativo
# 20604                   0.0              1.0              0.500000   Negativo
# 20623                   0.0              1.0              0.333333   Negativo
# 20673                   0.0              1.0              0.250000   Negativo
# 20690                   0.0              1.0              0.250000   Negativo
# 20710                   0.0              1.0              0.050000   Negativo
# 20711                   0.0              1.0              0.333333   Negativo
# 20723                   0.0              1.0              0.333333   Negativo
# 20734                   0.0              1.0              0.250000   Negativo
#
# [575 rows x 10 columns]

# %% [markdown]
# ### Encontrar as n palavras mais frequentes
#
# Foi feita uma função para se obter as palavras mais frequentes em um conjunto de reviews. No caso as reviews estão agrupadas pela nota dada ao produto.

# %%
def get_top_n_words(dataframe, n=None):
    
    # Encontra as palavras de maior frequência em um corpus e retorna como um par palavra, nº de ocorrências
    
    corpus = []
    for linha in dataframe.itertuples():
        corpus.append(linha[4])
    
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key = lambda x: x[1], reverse=True)

    return words_freq[:n]

# %%
top_w_1 = pd.DataFrame(get_top_n_words(e_set_rev_1,n = 10),columns = ['Palavra','Frequência'])
top_w_1
# Out:
#     Palavra  Frequência
# 0   produto        5511
# 1   receber        3576
# 2       ser        3170
# 3   comprar        2312
# 4  entregar        2199
# 5       ter        1529
# 6    chegar        1450
# 7       vir        1423
# 8     estar        1255
# 9     ainda        1232

# %%
top_w_2 = pd.DataFrame(get_top_n_words(e_set_rev_2,n = 10),columns = ['Palavra','Frequência'])
top_w_2
# Out:
#     Palavra  Frequência
# 0   produto        1286
# 1       ser         813
# 2   receber         672
# 3       vir         495
# 4  entregar         484
# 5   comprar         470
# 6       ter         386
# 7    chegar         367
# 8     estar         297
# 9     ainda         254

# %%
top_w_3 = pd.DataFrame(get_top_n_words(e_set_rev_3,n = 10),columns = ['Palavra','Frequência'])
top_w_3
# Out:
#     Palavra  Frequência
# 0   produto        1951
# 1       ser        1221
# 2       vir         772
# 3   receber         770
# 4       ter         696
# 5       bom         684
# 6  entregar         652
# 7    chegar         588
# 8   comprar         509
# 9     prazo         502

# %%
top_w_4 = pd.DataFrame(get_top_n_words(e_set_rev_4,n = 10),columns = ['Palavra','Frequência'])
top_w_4
# Out:
#       Palavra  Frequência
# 0     produto        2681
# 1         bom        1518
# 2       prazo        1394
# 3         ser        1147
# 4    entregar        1056
# 5      chegar         940
# 6       antes         762
# 7  recomendar         596
# 8     entrega         587
# 9         vir         581

# %%
top_w_5 = pd.DataFrame(get_top_n_words(e_set_rev_5,n = 10),columns = ['Palavra','Frequência'])
top_w_5
# Out:
#       Palavra  Frequência
# 0     produto        8654
# 1       prazo        5680
# 2       antes        4481
# 3    entregar        4019
# 4         bom        3999
# 5  recomendar        3577
# 6      chegar        3505
# 7         bem        2274
# 8         ser        2234
# 9     entrega        1958

# %% [markdown]
# Analisando as palavras mais frequêntes encontradas em cada agrupamento de reviews vemos que há nos reviews de notas mais altos palavras como "bom", "recomendar","bem" e "antes" estão mais presentes.
#
# Em contrapartida, vemos que o que diferencia as reviews de nota mais baixa é apenas a palavra "ainda", que provavelmente está associada ao fato de o produto não ter sido entregue.
#
# As palavras comuns a todas as reviews referem-se a palavras frequêntes no contexto analisado. Palavras como "produto","prazo","entregar" estaram provavelmente em todas as reviews e não possuem valor de sentimento atrelados a elas.
